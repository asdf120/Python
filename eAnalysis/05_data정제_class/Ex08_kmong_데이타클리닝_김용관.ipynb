# %% [markdown]
# # 데이타 크리닝 연습

# %%
import pandas as pd

# 판다스 데이터프레임(DataFrame)을 출력할 때, 최대 출력할 수 있는 컬럼을 100개로 늘려줍니다.
# 이렇게 해야 데이터를 분석할 때 출력해서 확인하기 편합니다.
pd.options.display.max_columns = 100

# %% [markdown]
# ### 데이터 로딩하기
#
# **kmong-conversion.csv**
#
# 먼저 크몽의 로그 데이터를 하나씩 가져오겠습니다. 가장 처음 가져올 데이터는 크몽의 가장 핵심 데이터라고 할 수 있는 ```kmong-conversion.csv``` 입니다. 여기에는 사용자가 크몽의 웹사이트/모바일 서비스에서 활동한 모든 활동 기록(activity)이 상세하게 담겨져 있으며, 이 정보를 바탕으로 데이터를 분석하여 사용자의 패턴을 유추할 수 있습니다. 컬럼 정보는 다음과 같습니다.
#
# * ```eventcategory```: 앱의 이벤트에 대한 카테고리입니다. 크게 다음의 종류가 있습니다.
#   - ```install```: 앱설치
#   - ```launch```: 앱실행
#   - ```deeplinkLaunch```: 딥링크 통한 앱실행
#   - ```goal```: 앱 내에서의 활동 여부
#   - ```exit```: 앱 종료
#   - ```foreground```, background```: 앱을 foreground, background로 전환
#   - ```launchlnSession```: Session의 시작.
# * ```isfirstactivity```: 해당 이벤트가 해당 유저에 한하여 첫 번째인지 혹은 두 번째 이상인지를 알려주는 값입니다.
#   - boolean 형식으로, 해당 이벤트가 해당 유저에 한하여 첫 번째 이벤트이면 True, 아니면 False를 갖습니다.
# * ```apppackagename```: 앱의 패키지의 고유한 이름입니다. 안드로이드의 경우 applicationId을, iOS의 경우 Bundle ID를 가져오게 됩니다.
# * ```appversion```: kmong 어플리케이션의 버전입니다.
# * ```devicetype```: 사용자가 kmong app을 실행하고 있는 기기의 제품명입니다.
# * ```devicemanufacturer```: 사용자가 kmong app을 실행하고 있는 기기의 제조회사입니다.
# * ```osversion```: 사용자가 kmong app을 실행하고 있는 기기의 os 버전입니다.
# * ```canonicaldeviceuuid```: 사용자가 kmong app을 실행하고 있는 기기의 고유 식별자입니다. (사용자를 구분하는 식별자로 이용할 수 있습니다)
# * ```sourcetype```: 해당 로그를 만든 고객이 유입된 경로입니다. 유료 광고 채널, 바이럴 채널, 앱 마켓 등으로 구분합니다.
# * ```channel```: sourcetype과 동일하지만 조금 더 세분화되어 있습니다.
#   - unattributed, WEB, google-play, m_naver, google, (not set), google.adwords, m_naverpowercontents, pc_naver, apple.searchads, facebook, m_daum
# * ```params_campaign```: 마케터가 입력한 캠페인 파라미터 중 캠페인명입니다.
# * ```params_medium```: 마케터가 입력한 캠페인 파라미터 중 매체입니다.
# * ```params_term```: 마케터가 입력한 캠페인 파라미터 중 키워드입니다.
# * ```inappeventcategory```: 인앱이벤트 식별자값으로 인앱이벤트를 지칭하는 3개의 값(category > action > label) 중 가장 상위에 속하는 구분값입니다.
#   - ```eventcategory```가 goal인 경우에만 제공됩니다.
#   - 차후에 읽어올 funnel 데이터셋과 연결할 수 있습니다.
#   - ex) seller_selling_history.view, gig_detail.view
# * ```inappeventlabel```: categoryid와 동일합니다.
#   - 차후에 읽어올 category 데이터셋과 연결할 수 있습니다.
#   - 인앱이벤트를 지칭하는 3개의 값(category > action > label) 중 마지막에 속하는 구분값입니다.
# * ```eventdatetime```: 모바일 클라이언트 상에서의 실제 이벤트 발생시간입니다. ISO 8601 표준에 따라서 제공됩니다.
# * ```isfirstgoalactivity```: goal 이벤트의 경우, 해당 Goal Label, Description, Key, Category를 가진 이벤트가 해당 유저에 한하여 첫 번째인지 혹은 두 번째 이상 인지를 알려주는 boolean 값입니다. 예를 들어 동일한 유저로부터 두 번 이상의 같은 Goal 이벤트가 발생한 경우(e.g. 동일한 물건 재구매 등) 이 값은 false가 됩니다.
#
# * ```event_rank```: 데이터를 정렬하는데 필요한 컬럼입니다. log엔 기록되지 않으며, DS_School에서 제공하는 전처리된 컬럼입니다.

# %%
raw_log = pd.read_csv("data/kmong/kmong-conversion.csv")

print(raw_log.shape)

raw_log.head()
# Out:
# (434244, 19)
#   eventcategory isfirstactivity   apppackagename appversion devicetype  \
# 0          goal           False    com.kmong.iOS      4.0.4     iPhone
# 1          goal           False  com.kmong.kmong      3.3.5   SM-N935S
# 2          goal           False    com.kmong.iOS      4.0.4     iPhone
# 3    foreground             NaN    com.kmong.iOS      4.0.4     iPhone
# 4          goal           False    com.kmong.iOS      4.0.4     iPhone
#
#   devicemanufacturer   osversion                   canonicaldeviceuuid  \
# 0              Apple   iOS11.4.1  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957
# 1            samsung  Android7.0  8a871e50-0717-4aed-9bad-04ac3c3793be
# 2              Apple     iOS12.0  A9E5778A-8F3D-4597-9718-74BF953A9F64
# 3              Apple   iOS11.4.1  168761CB-CB67-4592-867D-52780D651297
# 4              Apple   iOS11.4.1  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D
#
#      sourcetype       channel params_campaign params_medium params_term  \
# 0  unattributed  unattributed             NaN           NaN         NaN
# 1  unattributed  unattributed             NaN           NaN         NaN
# 2  unattributed  unattributed             NaN           NaN         NaN
# 3           NaN           NaN             NaN           NaN         NaN
# 4         viral           WEB             NaN           NaN         NaN
#
#        inappeventcategory  inappeventlabel              eventdatetime  \
# 0               home.view              NaN  2018-09-28T00:00:00+09:00
# 1         gig_detail.view          41201.0  2018-09-28T00:00:00+09:00
# 2       inbox_detail.view              NaN  2018-09-28T00:00:00+09:00
# 3                     NaN              NaN  2018-09-28T00:00:01+09:00
# 4  buyer_order_track.view              NaN  2018-09-28T00:00:02+09:00
#
#                                 rowuuid isfirstgoalactivity  event_rank
# 0  fd2a188c-bc9b-4702-9c47-b546b2614817               False        True
# 1  e62dccef-dd70-4415-8a33-c8324ddaed38               False        True
# 2  14eb3197-db83-493a-b7be-83582960c40b               False        True
# 3  f9bb91af-248b-44dc-9f5c-1c00b37ea97b                 NaN        True
# 4  236e9946-7801-4898-b609-06c8ab1139dc               False        True

# %%
dir(raw_log.columns)

# %% [markdown]
# **kmong-funnel.csv**
#
# 그 다음 가져올 데이터셋은 퍼널(Funnel) 정보를 나타내는 ```kmong-funnel.csv``` 입니다. 퍼널은 사용자가 서비스에 접속한 뒤 상품을 구매하기까지의 모든 경로를 구조화 한 것을 의미합니다.
#
# 사용자가 특정 상품을 결제하기 위해선, 해당 상품의 설명을 적은 페이지를 방문해야 하며, 상품 설명 페이지를 방문하기 위해서는 해당 상품이 리스트되어있는 페이지를 방문해야 합니다. 이런 방식으로 웹사이트를 설명하는 것을 일명 퍼널이라고 합니다.
#
# 이 퍼널 정보를 이용해 사용자가 상품을 구매하는 전환(Conversion) 여부, 내지는 서비스를 이탈하는 이탈(Churn) 여부를 추적할 수 있으며, 이를 통해서 웹사이트나 모바일서비스를 개선하여 전환율을 높이고 이탈률을 낮출 수 있습니다. 크몽에서는 서비스에서 사용하는 퍼널에 대한 설명을 ```kmong-funnel.csv``` 파일에 저장해두고 있습니다.

# %%
raw_funnel = pd.read_csv("data/kmong/kmong-funnel.csv")

print(raw_funnel.shape)

raw_funnel.head()
# Out:
# (53, 6)
#     Lv2         viewid  viewid desc  Lv1 funnel name funnel desc
# 0  1100           home        홈 (탭)   11        home           홈
# 1  1210  category_list  카테고리 목록 (탭)   12    category        카테고리
# 2  1200   category_gig    카테고리-상품목록   12    category        카테고리
# 3  1300         search           검색   13      search          검색
# 4  1301     search_gig      검색-상품목록   13      search          검색

# %% [markdown]
# **kmong-category.csv**
#
# 마지막으로 가져올 데이터셋은 크몽에서 판매하는 상품의 카테고리를 나타내는 ```kmong-category.csv``` 입니다. 크몽에서는 디자인, 번역, 컨텐츠 제작등 다양한 상품을 판매하고 있는데, 이 상품을 그룹화하고 정리할 수 있도록 만든 것이 카테고리입니다. 크몽에서는 이 값을 ```kmong-category.csv``` 라는 변수에 저장해두고 있습니다.

# %%
raw_category = pd.read_csv("data/kmong/kmong-category.csv")


print(raw_category.shape)

raw_category.head()
# Out:
# (245, 9)
#    depth  categoryid categoryname  cat1_id  cat2_id  cat3_id      cat1 cat2  \
# 0      1           1          디자인        1      NaN      NaN       디자인  NaN
# 1      1           2          마케팅        2      NaN      NaN       마케팅  NaN
# 2      1           3        번역·통역        3      NaN      NaN     번역·통역  NaN
# 3      1           4         문서작성        4      NaN      NaN      문서작성  NaN
# 4      1           6     IT·프로그래밍        6      NaN      NaN  IT·프로그래밍  NaN
#
#   cat3
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %% [markdown]
# ### 데이터 정리하기
#
# 먼저 가장 기본이 되는 ```kmong-conversion.csv```부터 정리하겠습니다. 이 데이터에는 사용자의 활동 기록을 자세하게 정리하였다는 장점이 있지만, 데이터가 다소 지저분하게 기록되어 있기 때문에, 이 데이터를 정리하지 않은 채 분석하는 것은 많은 시간을 낭비하게 될 것 같습니다. 그러므로 이번 기회에 데이터를 깔끔하게 정리하여 저장하도록 하겠습니다.

# %% [markdown]
# **1. ```canonicaldeviceuuid``` 컬럼명을 ```userid``` 컬럼명으로 바꿔주세요.**
#
# 먼저 ```canonicaldeviceuuid```라는 컬럼명을 바꾸고 싶습니다. 이 컬럼은 크몽을 이용하는 한 명의 사용자를 나타내는 중요한 정보임에는 틀림없지만, ```canonicaldeviceuuid```라는 표현 자체가 크몽, 내지는 다른 몇몇 분야에서만 쓰이는 표현이기 때문에 이 데이터를 처음 보는 사람의 입장에서는 직관적으로 이해하기 힘듭니다. 그렇기 때문에 이 컬럼의 이름을 많은 사람들이 직관적으로 이해할 수 있는 ```userid```로 바꾸고 싶습니다. 최종적으로 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe", style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>canonicaldeviceuuid</th>
#             <th>userid</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#         </tr>
#     </tbody>
# </table>

# %%
# Write your code here!
temp = raw_log.rename({'canonicaldeviceuuid':'userid'},axis='columns')
temp
# Out:
#        eventcategory isfirstactivity   apppackagename appversion devicetype  \
# 0               goal           False    com.kmong.iOS      4.0.4     iPhone
# 1               goal           False  com.kmong.kmong      3.3.5   SM-N935S
# 2               goal           False    com.kmong.iOS      4.0.4     iPhone
# 3         foreground             NaN    com.kmong.iOS      4.0.4     iPhone
# 4               goal           False    com.kmong.iOS      4.0.4     iPhone
# ...              ...             ...              ...        ...        ...
# 434239          goal           False  com.kmong.kmong      3.3.5   SM-G930L
# 434240          goal           False  com.kmong.kmong      3.3.5   SM-N950N
# 434241          goal           False  com.kmong.kmong      3.3.5   SM-G930L
# 434242          exit             NaN  com.kmong.kmong      3.3.5   SM-N950N
# 434243          goal           False  com.kmong.kmong      3.3.5   SM-G965N
#
#        devicemanufacturer     osversion                                userid  \
# 0                   Apple     iOS11.4.1  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957
# 1                 samsung    Android7.0  8a871e50-0717-4aed-9bad-04ac3c3793be
# 2                   Apple       iOS12.0  A9E5778A-8F3D-4597-9718-74BF953A9F64
# 3                   Apple     iOS11.4.1  168761CB-CB67-4592-867D-52780D651297
# 4                   Apple     iOS11.4.1  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D
# ...                   ...           ...                                   ...
# 434239            samsung  Android8.0.0  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3
# 434240            samsung  Android8.0.0  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f
# 434241            samsung  Android8.0.0  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3
# 434242            samsung  Android8.0.0  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f
# 434243            samsung  Android8.0.0  965b53e9-f6d6-4a9d-827e-e60c5eb52bb8
#
#           sourcetype       channel   params_campaign params_medium  \
# 0       unattributed  unattributed               NaN           NaN
# 1       unattributed  unattributed               NaN           NaN
# 2       unattributed  unattributed               NaN           NaN
# 3                NaN           NaN               NaN           NaN
# 4              viral           WEB               NaN           NaN
# ...              ...           ...               ...           ...
# 434239      stranger        google  mweb-app-install           cpc
# 434240  unattributed  unattributed               NaN           NaN
# 434241      stranger        google  mweb-app-install           cpc
# 434242           NaN           NaN               NaN           NaN
# 434243  unattributed  unattributed               NaN           NaN
#
#        params_term      inappeventcategory  inappeventlabel  \
# 0              NaN               home.view              NaN
# 1              NaN         gig_detail.view          41201.0
# 2              NaN       inbox_detail.view              NaN
# 3              NaN                     NaN              NaN
# 4              NaN  buyer_order_track.view              NaN
# ...            ...                     ...              ...
# 434239         NaN         gig_detail.view            104.0
# 434240         NaN               home.view              NaN
# 434241         NaN       category_gig.view            104.0
# 434242         NaN                     NaN              NaN
# 434243         NaN         search_gig.view              NaN
#
#                     eventdatetime                               rowuuid  \
# 0       2018-09-28T00:00:00+09:00  fd2a188c-bc9b-4702-9c47-b546b2614817
# 1       2018-09-28T00:00:00+09:00  e62dccef-dd70-4415-8a33-c8324ddaed38
# 2       2018-09-28T00:00:00+09:00  14eb3197-db83-493a-b7be-83582960c40b
# 3       2018-09-28T00:00:01+09:00  f9bb91af-248b-44dc-9f5c-1c00b37ea97b
# 4       2018-09-28T00:00:02+09:00  236e9946-7801-4898-b609-06c8ab1139dc
# ...                           ...                                   ...
# 434239  2018-09-29T23:59:52+09:00  9d9fd3d8-30c5-49e5-8480-41b536eb4edb
# 434240  2018-09-29T23:59:53+09:00  88653965-4aff-4d2e-8dd6-88f25ac82595
# 434241  2018-09-29T23:59:53+09:00  40bdc87e-265a-4cc2-a1d4-f1da96a0b9dc
# 434242  2018-09-29T23:59:54+09:00  f44a488b-1a8b-4f53-ad8e-8b21c695925b
# 434243  2018-09-29T23:59:58+09:00  5fbb87c9-4d62-4eea-a75c-cab1a3af1d52
#
#        isfirstgoalactivity  event_rank
# 0                    False        True
# 1                    False        True
# 2                    False        True
# 3                      NaN        True
# 4                    False        True
# ...                    ...         ...
# 434239               False        True
# 434240               False        True
# 434241               False        True
# 434242                 NaN        True
# 434243               False        True
#
# [434244 rows x 19 columns]

# %% [markdown]
# **2. ```eventdatetime``` 컬럼은 datetime 형태로 바꾼 뒤 연/월/일/시/분/초 데이터를 추출해주세요.**
#
# ```eventdatetime```은 날짜와 시간 형식으로 표현되어 있습니다. (ex: 2018-01-01T00:00:00+09:00) 하지만 이 데이터를 처음 읽을 때, 판다스는 날짜 데이터로 인식하지 않고 문자열(object, 내지는 string)으로 인식합니다. 이 데이터를 날짜와 시간 형식을 나타내는 ```datetime``` 형태로 바꾼 뒤, 연/월/일/시/분/초 데이터를 추출해주세요. 최종적으로 다음의 결과가 나와야 합니다.
#
# ( 아래 결과를 보면, 	2018-09-27 15:00:00 형식으로 출력되지만, 버전에 따라 다르게 출력될 수 있다 )

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>eventdatetime</th>
#             <th>eventdatetime_year</th>
#             <th>eventdatetime_month</th>
#             <th>eventdatetime_day</th>
#             <th>eventdatetime_hour</th>
#             <th>eventdatetime_minute</th>
#             <th>eventdatetime_second</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#         </tr>
#     </tbody>
# </table>

# %%
# Write your code here!
from datetime import datetime
temp['eventdatetime']=pd.to_datetime(temp['eventdatetime'])
temp['eventdatetime_year']=temp['eventdatetime'].dt.year
temp['eventdatetime_month']=temp['eventdatetime'].dt.month
temp['eventdatetime_day']=temp['eventdatetime'].dt.day
temp['eventdatetime_hour']=temp['eventdatetime'].dt.hour
temp['eventdatetime_minute']=temp['eventdatetime'].dt.minute
temp['eventdatetime_second']=temp['eventdatetime'].dt.second
temp.head(5)
# Out:
#   eventcategory isfirstactivity   apppackagename appversion devicetype  \
# 0          goal           False    com.kmong.iOS      4.0.4     iPhone
# 1          goal           False  com.kmong.kmong      3.3.5   SM-N935S
# 2          goal           False    com.kmong.iOS      4.0.4     iPhone
# 3    foreground             NaN    com.kmong.iOS      4.0.4     iPhone
# 4          goal           False    com.kmong.iOS      4.0.4     iPhone
#
#   devicemanufacturer   osversion                                userid  \
# 0              Apple   iOS11.4.1  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957
# 1            samsung  Android7.0  8a871e50-0717-4aed-9bad-04ac3c3793be
# 2              Apple     iOS12.0  A9E5778A-8F3D-4597-9718-74BF953A9F64
# 3              Apple   iOS11.4.1  168761CB-CB67-4592-867D-52780D651297
# 4              Apple   iOS11.4.1  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D
#
#      sourcetype       channel params_campaign params_medium params_term  \
# 0  unattributed  unattributed             NaN           NaN         NaN
# 1  unattributed  unattributed             NaN           NaN         NaN
# 2  unattributed  unattributed             NaN           NaN         NaN
# 3           NaN           NaN             NaN           NaN         NaN
# 4         viral           WEB             NaN           NaN         NaN
#
#        inappeventcategory  inappeventlabel             eventdatetime  \
# 0               home.view              NaN 2018-09-28 00:00:00+09:00
# 1         gig_detail.view          41201.0 2018-09-28 00:00:00+09:00
# 2       inbox_detail.view              NaN 2018-09-28 00:00:00+09:00
# 3                     NaN              NaN 2018-09-28 00:00:01+09:00
# 4  buyer_order_track.view              NaN 2018-09-28 00:00:02+09:00
#
#                                 rowuuid isfirstgoalactivity  event_rank  \
# 0  fd2a188c-bc9b-4702-9c47-b546b2614817               False        True
# 1  e62dccef-dd70-4415-8a33-c8324ddaed38               False        True
# 2  14eb3197-db83-493a-b7be-83582960c40b               False        True
# 3  f9bb91af-248b-44dc-9f5c-1c00b37ea97b                 NaN        True
# 4  236e9946-7801-4898-b609-06c8ab1139dc               False        True
#
#    eventdatetime_year  eventdatetime_month  eventdatetime_day  \
# 0                2018                    9                 28
# 1                2018                    9                 28
# 2                2018                    9                 28
# 3                2018                    9                 28
# 4                2018                    9                 28
#
#    eventdatetime_hour  eventdatetime_minute  eventdatetime_second
# 0                   0                     0                     0
# 1                   0                     0                     0
# 2                   0                     0                     0
# 3                   0                     0                     1
# 4                   0                     0                     2

# %% [markdown]
# **3. ```osversion``` 컬럼에 들어가 있는 정보를 여러 개의 컬럼으로 나눠주세요.**
#
# ```osversion``` 컬럼을 사용자가 현재 사용하고 있는 스마트폰 디바이스의 운영체제와 그 버전을 나타냅니다. 여기에는 크게 1) 현재 사용하고 있는 운영체제(Operating System, 이하 OS), 2) 그리고 해당 운영체제의 버전(version) 정보가 기록되어 있습니다. 가령 ```osversion```에 들어있는 값이 iOS11.4.1이라면, 이 스마트폰의 운영체제는 iOS(아이폰), 운영체제의 버전은 11.4.1 이라는 사실을 알 수 있습니다.
#
# 이 데이터를 차후 데이터 분석용으로 다루기 쉽게, ```ostype(clean)```과 ```osversion(clean)```이라는 두 개의 컬럼으로 분리하고 싶습니다. 가령 에를 들자면
#
#   * ```osversion``` 컬럼값이 iOS11.4.1이라면, 새로운 컬럼인 ```ostype(clean)```에는 iOS가, ```osversion(clean)```에는 11.4.1이 들어가야 합니다.
#   * ```osversion``` 컬럼값이 Android7.0이라면, 새로운 컬럼인 ```ostype(clean)```에는 Android가, ```osversion(clean)```에는 7.0이 들어가야 합니다.
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>osversion</th>
#             <th>ostype(clean)</th>
#             <th>osversion(clean)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>iOS11.4.1</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>Android7.0</td>
#             <td>Android</td>
#             <td>7.0</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>iOS12.0</td>
#             <td>iOS</td>
#             <td>12.0</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>iOS11.4.1</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>iOS11.4.1</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#         </tr>
#     </tbody>
# </table>

# %%
# Write your code here!
import re
osversion_list = []
for i in raw_log['osversion']:
    temp_list = []
    version_regax = re.compile('[^A-Za-z]{1,7}')
    type_regax = re.compile('[A-Za-z]{3,10}')
    osversion=version_regax.search(i).group()
    ostype = type_regax.search(i).group()
    temp_list.append(i)
    temp_list.append(ostype)
    temp_list.append(osversion)
    osversion_list.append(temp_list)
os = pd.DataFrame(osversion_list,columns=['osversion','ostype(clean)','osversion(clean)'])
os
temp = pd.concat([temp,os],axis=1)

# 광웅이방식
# temp['ostype(clean)'] = [i.split('1')[0] if i[0]=='i' else 'Andriod' for i in temp['osversion'] ]
# temp['osversion(clean)'] = [i.split('S')[-1] if i[0]=='i' else i.split('d')[-1] for i in temp['osversion']]
# temp[['osversion', 'ostype(clean)', 'osversion(clean)']]

# %% [markdown]
# **4. ```devicemanufacturer``` 컬럼 정보를 정리해주세요.**
#
# ```devicemanufacturer``` 컬럼은 사용자가 현재 사용하고 있는 스마트폰 디바이스를 제조한 제조사의 정보가 들어가 있습니다. 가령 ```samsung```이라고 적혀있으면 이 스마트폰은 삼성전자가 제조했다고 볼 수 있고, ```LG Electronics```라고 적혀있으면 이 스마트폰은 LG전자가 제조했다고 볼 수 있습니다.
#
# 하지만 ```devicemanufacturer``` 컬럼에는 이 외에도 샤오미(Xiaomi), 폭스콘(Foxconn), 팬텍(PANTECH), 화웨이(HUAWEI)와 같은 마이너한 제조사 정보도 들어가 있습니다. 이 제조사들은 전체 사용자의 2%도 되지 않기 때문에, 이 데이터를 무시하거나 하나의 값(ex: Others)으로 통일해주면 데이터 분석가가 더 효율적으로 데이터를 분석할 수 있을 것 같습니다.
#
# 그러므로 ```devicemanufacturer``` 컬럼의 값을 정리해보겠습니다. 정리 방식은 다음과 같습니다.
#
#  * ```samsung```이라고 적혀있는 값은 앞 글자를 대문자로 바꿉니다. (=```Samsung```)
#  * ```LGE```와 ```LG Electronics```라는 값은 ```LG```로 통일합니다.
#  * ```Apple```, ```Samsung```, ```LG```를 제외한 나머지는 ```Other```로 묶습니다.
#
# 최종적으로는 다음의 결과가 나와야 합니다.
#
#   * Samsung - 230313
#   * Apple - 163566
#   * LG - 32649
#   * Others - 7716

# %%
# Write your code here!
temp.loc[(temp['devicemanufacturer']=='samsung'), 'devicemanufacturer'] = 'Samsung'
temp.loc[(temp['devicemanufacturer']=='LGE') | (temp['devicemanufacturer']=='LG Electronics'), 'devicemanufacturer'] = 'LG'
temp.loc[(temp['devicemanufacturer']!='LG') & (temp['devicemanufacturer']!='Samsung')&(temp['devicemanufacturer']!='Apple'), 'devicemanufacturer'] = 'Others'

temp['devicemanufacturer'].value_counts()
temp['devicemanufacturer(clean)'] = [i for i in temp['devicemanufacturer']]
temp['devicemanufacturer(clean)']
temp
# Out:
#        eventcategory isfirstactivity   apppackagename appversion devicetype  \
# 0               goal           False    com.kmong.iOS      4.0.4     iPhone
# 1               goal           False  com.kmong.kmong      3.3.5   SM-N935S
# 2               goal           False    com.kmong.iOS      4.0.4     iPhone
# 3         foreground             NaN    com.kmong.iOS      4.0.4     iPhone
# 4               goal           False    com.kmong.iOS      4.0.4     iPhone
# ...              ...             ...              ...        ...        ...
# 434239          goal           False  com.kmong.kmong      3.3.5   SM-G930L
# 434240          goal           False  com.kmong.kmong      3.3.5   SM-N950N
# 434241          goal           False  com.kmong.kmong      3.3.5   SM-G930L
# 434242          exit             NaN  com.kmong.kmong      3.3.5   SM-N950N
# 434243          goal           False  com.kmong.kmong      3.3.5   SM-G965N
#
#        devicemanufacturer     osversion                                userid  \
# 0                   Apple     iOS11.4.1  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957
# 1                 Samsung    Android7.0  8a871e50-0717-4aed-9bad-04ac3c3793be
# 2                   Apple       iOS12.0  A9E5778A-8F3D-4597-9718-74BF953A9F64
# 3                   Apple     iOS11.4.1  168761CB-CB67-4592-867D-52780D651297
# 4                   Apple     iOS11.4.1  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D
# ...                   ...           ...                                   ...
# 434239            Samsung  Android8.0.0  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3
# 434240            Samsung  Android8.0.0  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f
# 434241            Samsung  Android8.0.0  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3
# 434242            Samsung  Android8.0.0  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f
# 434243            Samsung  Android8.0.0  965b53e9-f6d6-4a9d-827e-e60c5eb52bb8
#
#           sourcetype       channel   params_campaign params_medium  \
# 0       unattributed  unattributed               NaN           NaN
# 1       unattributed  unattributed               NaN           NaN
# 2       unattributed  unattributed               NaN           NaN
# 3                NaN           NaN               NaN           NaN
# 4              viral           WEB               NaN           NaN
# ...              ...           ...               ...           ...
# 434239      stranger        google  mweb-app-install           cpc
# 434240  unattributed  unattributed               NaN           NaN
# 434241      stranger        google  mweb-app-install           cpc
# 434242           NaN           NaN               NaN           NaN
# 434243  unattributed  unattributed               NaN           NaN
#
#        params_term      inappeventcategory  inappeventlabel  \
# 0              NaN               home.view              NaN
# 1              NaN         gig_detail.view          41201.0
# 2              NaN       inbox_detail.view              NaN
# 3              NaN                     NaN              NaN
# 4              NaN  buyer_order_track.view              NaN
# ...            ...                     ...              ...
# 434239         NaN         gig_detail.view            104.0
# 434240         NaN               home.view              NaN
# 434241         NaN       category_gig.view            104.0
# 434242         NaN                     NaN              NaN
# 434243         NaN         search_gig.view              NaN
#
#                    eventdatetime                               rowuuid  \
# 0      2018-09-28 00:00:00+09:00  fd2a188c-bc9b-4702-9c47-b546b2614817
# 1      2018-09-28 00:00:00+09:00  e62dccef-dd70-4415-8a33-c8324ddaed38
# 2      2018-09-28 00:00:00+09:00  14eb3197-db83-493a-b7be-83582960c40b
# 3      2018-09-28 00:00:01+09:00  f9bb91af-248b-44dc-9f5c-1c00b37ea97b
# 4      2018-09-28 00:00:02+09:00  236e9946-7801-4898-b609-06c8ab1139dc
# ...                          ...                                   ...
# 434239 2018-09-29 23:59:52+09:00  9d9fd3d8-30c5-49e5-8480-41b536eb4edb
# 434240 2018-09-29 23:59:53+09:00  88653965-4aff-4d2e-8dd6-88f25ac82595
# 434241 2018-09-29 23:59:53+09:00  40bdc87e-265a-4cc2-a1d4-f1da96a0b9dc
# 434242 2018-09-29 23:59:54+09:00  f44a488b-1a8b-4f53-ad8e-8b21c695925b
# 434243 2018-09-29 23:59:58+09:00  5fbb87c9-4d62-4eea-a75c-cab1a3af1d52
#
#        isfirstgoalactivity  event_rank  eventdatetime_year  \
# 0                    False        True                2018
# 1                    False        True                2018
# 2                    False        True                2018
# 3                      NaN        True                2018
# 4                    False        True                2018
# ...                    ...         ...                 ...
# 434239               False        True                2018
# 434240               False        True                2018
# 434241               False        True                2018
# 434242                 NaN        True                2018
# 434243               False        True                2018
#
#         eventdatetime_month  eventdatetime_day  eventdatetime_hour  \
# 0                         9                 28                   0
# 1                         9                 28                   0
# 2                         9                 28                   0
# 3                         9                 28                   0
# 4                         9                 28                   0
# ...                     ...                ...                 ...
# 434239                    9                 29                  23
# 434240                    9                 29                  23
# 434241                    9                 29                  23
# 434242                    9                 29                  23
# 434243                    9                 29                  23
#
#         eventdatetime_minute  eventdatetime_second     osversion  \
# 0                          0                     0     iOS11.4.1
# 1                          0                     0    Android7.0
# 2                          0                     0       iOS12.0
# 3                          0                     1     iOS11.4.1
# 4                          0                     2     iOS11.4.1
# ...                      ...                   ...           ...
# 434239                    59                    52  Android8.0.0
# 434240                    59                    53  Android8.0.0
# 434241                    59                    53  Android8.0.0
# 434242                    59                    54  Android8.0.0
# 434243                    59                    58  Android8.0.0
#
#        ostype(clean) osversion(clean) devicemanufacturer(clean)
# 0                iOS           11.4.1                     Apple
# 1            Android              7.0                   Samsung
# 2                iOS             12.0                     Apple
# 3                iOS           11.4.1                     Apple
# 4                iOS           11.4.1                     Apple
# ...              ...              ...                       ...
# 434239       Android            8.0.0                   Samsung
# 434240       Android            8.0.0                   Samsung
# 434241       Android            8.0.0                   Samsung
# 434242       Android            8.0.0                   Samsung
# 434243       Android            8.0.0                   Samsung
#
# [434244 rows x 29 columns]

# %% [markdown]
# **5. ```channel``` 컬럼 정보를 정리해주세요.**
#
# ```channel``` 컬럼을 사용자가 크몽 서비스에 유입된 경로를 기록한 정보입니다. 여기에는 웹(WEB), 구글(ex: google-play, google, google.adwords, etc), 네이버(ex: m_naver, m_naverpowercontents, pc_naver)등이 기록되어 있습니다. 이 정보도 마찬가지로 데이터를 분석하기 어렵게 산재되어 있기 때문에, 깔끔하게 정리해주고 싶습니다. 정리 방식은 다음과 같습니다.
#
#   * 컬럼값에 google이라고 들어간 값(ex: google-play, google.adwords, etc)은 전부 google로 통일합니다.
#   * 컬럼값에 daum이라고 들어간 값(ex: m_daum, etc)은 전부 daum으로 통일합니다.
#   * 컬럼값이 naver라고 들어간 값(ex: m_naver, pc_naver, m_naverpowercontents, etc)은 전부 naver로 통일합니다.
#   * 컬럼값에 apple이라고 들어간 값(ex: apple.searchads, etc)은 전부 apple로 통일합니다.
#   * 컬럼값에 WEB이라고 들어간 값(ex: WEB)은 전부 web으로 통일합니다.
#
# 최종적으로는 다음의 결과가 나와야 합니다.
#
# * unattributed - 270834
# * web - 27639
# * google - 27235
# * (not set) - 2444
# * naver - 1224
# * daum - 966
# * apple - 697
# * facebook - 126

# %%
# Write your code here!

temp.loc[temp['channel'].str.contains('google',na=False),'channel'] = 'google'
temp.loc[temp['channel'].str.contains('daum',na=False),'channel'] = 'daum'
temp.loc[temp['channel'].str.contains('naver',na=False),'channel'] = 'naver'
temp.loc[temp['channel'].str.contains('apple',na=False),'channel'] = 'apple'
temp.loc[temp['channel'].str.contains('WEB',na=False),'channel'] = 'web'
temp['channel'].value_counts(dropna=True)

temp['viewcategory'] = [str(i).split('_')[0].split('.')[0] for i in temp['inappeventcategory']]


temp['channel(clean)'] = [i for i in temp['channel']]
# temp['channel(clean)']
temp.head()
# Out:
#   eventcategory isfirstactivity   apppackagename appversion devicetype  \
# 0          goal           False    com.kmong.iOS      4.0.4     iPhone
# 1          goal           False  com.kmong.kmong      3.3.5   SM-N935S
# 2          goal           False    com.kmong.iOS      4.0.4     iPhone
# 3    foreground             NaN    com.kmong.iOS      4.0.4     iPhone
# 4          goal           False    com.kmong.iOS      4.0.4     iPhone
#
#   devicemanufacturer   osversion                                userid  \
# 0              Apple   iOS11.4.1  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957
# 1            Samsung  Android7.0  8a871e50-0717-4aed-9bad-04ac3c3793be
# 2              Apple     iOS12.0  A9E5778A-8F3D-4597-9718-74BF953A9F64
# 3              Apple   iOS11.4.1  168761CB-CB67-4592-867D-52780D651297
# 4              Apple   iOS11.4.1  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D
#
#      sourcetype       channel params_campaign params_medium params_term  \
# 0  unattributed  unattributed             NaN           NaN         NaN
# 1  unattributed  unattributed             NaN           NaN         NaN
# 2  unattributed  unattributed             NaN           NaN         NaN
# 3           NaN           NaN             NaN           NaN         NaN
# 4         viral           web             NaN           NaN         NaN
#
#        inappeventcategory  inappeventlabel             eventdatetime  \
# 0               home.view              NaN 2018-09-28 00:00:00+09:00
# 1         gig_detail.view          41201.0 2018-09-28 00:00:00+09:00
# 2       inbox_detail.view              NaN 2018-09-28 00:00:00+09:00
# 3                     NaN              NaN 2018-09-28 00:00:01+09:00
# 4  buyer_order_track.view              NaN 2018-09-28 00:00:02+09:00
#
#                                 rowuuid isfirstgoalactivity  event_rank  \
# 0  fd2a188c-bc9b-4702-9c47-b546b2614817               False        True
# 1  e62dccef-dd70-4415-8a33-c8324ddaed38               False        True
# 2  14eb3197-db83-493a-b7be-83582960c40b               False        True
# 3  f9bb91af-248b-44dc-9f5c-1c00b37ea97b                 NaN        True
# 4  236e9946-7801-4898-b609-06c8ab1139dc               False        True
#
#    eventdatetime_year  eventdatetime_month  eventdatetime_day  \
# 0                2018                    9                 28
# 1                2018                    9                 28
# 2                2018                    9                 28
# 3                2018                    9                 28
# 4                2018                    9                 28
#
#    eventdatetime_hour  eventdatetime_minute  eventdatetime_second   osversion  \
# 0                   0                     0                     0   iOS11.4.1
# 1                   0                     0                     0  Android7.0
# 2                   0                     0                     0     iOS12.0
# 3                   0                     0                     1   iOS11.4.1
# 4                   0                     0                     2   iOS11.4.1
#
#   ostype(clean) osversion(clean) devicemanufacturer(clean) viewcategory  \
# 0           iOS           11.4.1                     Apple         home
# 1       Android              7.0                   Samsung          gig
# 2           iOS             12.0                     Apple        inbox
# 3           iOS           11.4.1                     Apple          nan
# 4           iOS           11.4.1                     Apple        buyer
#
#   channel(clean)
# 0   unattributed
# 1   unattributed
# 2   unattributed
# 3            NaN
# 4            web

# %% [markdown]
# **6. ```inappeventcategory``` 컬럼에 들어가 있는 정보를 여러 개의 컬럼으로 나눠주세요.**
#
# ```inappeventcategory```에는 사용자 액티비티를 나타내는 정보가 들어있습니다. 크몽에 방문한 고객이 상품 페이지를 보고 있는지, 구매를 진행중인지 등에 대한 정보가 이 컬럼에 담겨있다고 보시면 됩니다. 또한 ```inappeventcategory```에 있는 정보는 차후 퍼널(funnel) 데이터를 합치는데 사용되기도 합니다. 이 데이터를 정리해주세요. 정리 방식은 다음과 같습니다.
#
#   * ```viewcategory``` - ```inappeventcategory```에서 언더바(_)를 기준으로 왼쪽 텍스트만 가져옵니다.
#   * ```viewid``` - ```inappeventcategory```에서 점(.)의 왼쪽 텍스트만 가져옵니다.
#   * ```viewaction``` - ```inappeventcategory```에서 점(.)의 오른쪽 텍스트만 가져옵니다.
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>inappeventcategory</th>
#             <th>viewcategory</th>
#             <th>viewid</th>
#             <th>viewaction</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>home.view</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>gig_detail.view</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>inbox_detail.view</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>buyer_order_track.view</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#         </tr>
#     </tbody>
# </table>

# %%
# Write your code here!
temp.head()
# result_list = []
# for i in range(len(temp['inappeventcategory'])):
#     temp_list = []
#     viewCategory = str(temp['inappeventcategory'][i]).split('_')[0]
#     viewId = str(temp['inappeventcategory'][i]).split('.')[0]
#     viewAction = str(temp['inappeventcategory'][i]).split('.')[-1]
#     temp_list.append(viewCategory)
#     temp_list.append(viewId)
#     temp_list.append(viewAction)
    
#     result_list.append(temp_list)
# pd.DataFrame(result_list,columns=['viewcategory','viewid','viewaction'])

temp['viewcategory'] = [str(i).split('_')[0].split('.')[0] for i in temp['inappeventcategory']]
temp['viewid'] = [str(i).split('.')[0] for i in temp['inappeventcategory']]
temp['viewaction'] = [str(i).split('.')[-1] for i in temp['inappeventcategory']]
# temp[['viewcategory','viewid','viewaction']]
temp
# Out:
#        eventcategory isfirstactivity   apppackagename appversion devicetype  \
# 0               goal           False    com.kmong.iOS      4.0.4     iPhone
# 1               goal           False  com.kmong.kmong      3.3.5   SM-N935S
# 2               goal           False    com.kmong.iOS      4.0.4     iPhone
# 3         foreground             NaN    com.kmong.iOS      4.0.4     iPhone
# 4               goal           False    com.kmong.iOS      4.0.4     iPhone
# ...              ...             ...              ...        ...        ...
# 434239          goal           False  com.kmong.kmong      3.3.5   SM-G930L
# 434240          goal           False  com.kmong.kmong      3.3.5   SM-N950N
# 434241          goal           False  com.kmong.kmong      3.3.5   SM-G930L
# 434242          exit             NaN  com.kmong.kmong      3.3.5   SM-N950N
# 434243          goal           False  com.kmong.kmong      3.3.5   SM-G965N
#
#        devicemanufacturer     osversion                                userid  \
# 0                   Apple     iOS11.4.1  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957
# 1                 Samsung    Android7.0  8a871e50-0717-4aed-9bad-04ac3c3793be
# 2                   Apple       iOS12.0  A9E5778A-8F3D-4597-9718-74BF953A9F64
# 3                   Apple     iOS11.4.1  168761CB-CB67-4592-867D-52780D651297
# 4                   Apple     iOS11.4.1  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D
# ...                   ...           ...                                   ...
# 434239            Samsung  Android8.0.0  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3
# 434240            Samsung  Android8.0.0  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f
# 434241            Samsung  Android8.0.0  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3
# 434242            Samsung  Android8.0.0  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f
# 434243            Samsung  Android8.0.0  965b53e9-f6d6-4a9d-827e-e60c5eb52bb8
#
#           sourcetype       channel   params_campaign params_medium  \
# 0       unattributed  unattributed               NaN           NaN
# 1       unattributed  unattributed               NaN           NaN
# 2       unattributed  unattributed               NaN           NaN
# 3                NaN           NaN               NaN           NaN
# 4              viral           web               NaN           NaN
# ...              ...           ...               ...           ...
# 434239      stranger        google  mweb-app-install           cpc
# 434240  unattributed  unattributed               NaN           NaN
# 434241      stranger        google  mweb-app-install           cpc
# 434242           NaN           NaN               NaN           NaN
# 434243  unattributed  unattributed               NaN           NaN
#
#        params_term      inappeventcategory  inappeventlabel  \
# 0              NaN               home.view              NaN
# 1              NaN         gig_detail.view          41201.0
# 2              NaN       inbox_detail.view              NaN
# 3              NaN                     NaN              NaN
# 4              NaN  buyer_order_track.view              NaN
# ...            ...                     ...              ...
# 434239         NaN         gig_detail.view            104.0
# 434240         NaN               home.view              NaN
# 434241         NaN       category_gig.view            104.0
# 434242         NaN                     NaN              NaN
# 434243         NaN         search_gig.view              NaN
#
#                    eventdatetime                               rowuuid  \
# 0      2018-09-28 00:00:00+09:00  fd2a188c-bc9b-4702-9c47-b546b2614817
# 1      2018-09-28 00:00:00+09:00  e62dccef-dd70-4415-8a33-c8324ddaed38
# 2      2018-09-28 00:00:00+09:00  14eb3197-db83-493a-b7be-83582960c40b
# 3      2018-09-28 00:00:01+09:00  f9bb91af-248b-44dc-9f5c-1c00b37ea97b
# 4      2018-09-28 00:00:02+09:00  236e9946-7801-4898-b609-06c8ab1139dc
# ...                          ...                                   ...
# 434239 2018-09-29 23:59:52+09:00  9d9fd3d8-30c5-49e5-8480-41b536eb4edb
# 434240 2018-09-29 23:59:53+09:00  88653965-4aff-4d2e-8dd6-88f25ac82595
# 434241 2018-09-29 23:59:53+09:00  40bdc87e-265a-4cc2-a1d4-f1da96a0b9dc
# 434242 2018-09-29 23:59:54+09:00  f44a488b-1a8b-4f53-ad8e-8b21c695925b
# 434243 2018-09-29 23:59:58+09:00  5fbb87c9-4d62-4eea-a75c-cab1a3af1d52
#
#        isfirstgoalactivity  event_rank  eventdatetime_year  \
# 0                    False        True                2018
# 1                    False        True                2018
# 2                    False        True                2018
# 3                      NaN        True                2018
# 4                    False        True                2018
# ...                    ...         ...                 ...
# 434239               False        True                2018
# 434240               False        True                2018
# 434241               False        True                2018
# 434242                 NaN        True                2018
# 434243               False        True                2018
#
#         eventdatetime_month  eventdatetime_day  eventdatetime_hour  \
# 0                         9                 28                   0
# 1                         9                 28                   0
# 2                         9                 28                   0
# 3                         9                 28                   0
# 4                         9                 28                   0
# ...                     ...                ...                 ...
# 434239                    9                 29                  23
# 434240                    9                 29                  23
# 434241                    9                 29                  23
# 434242                    9                 29                  23
# 434243                    9                 29                  23
#
#         eventdatetime_minute  eventdatetime_second     osversion  \
# 0                          0                     0     iOS11.4.1
# 1                          0                     0    Android7.0
# 2                          0                     0       iOS12.0
# 3                          0                     1     iOS11.4.1
# 4                          0                     2     iOS11.4.1
# ...                      ...                   ...           ...
# 434239                    59                    52  Android8.0.0
# 434240                    59                    53  Android8.0.0
# 434241                    59                    53  Android8.0.0
# 434242                    59                    54  Android8.0.0
# 434243                    59                    58  Android8.0.0
#
#        ostype(clean) osversion(clean) devicemanufacturer(clean) viewcategory  \
# 0                iOS           11.4.1                     Apple         home
# 1            Android              7.0                   Samsung          gig
# 2                iOS             12.0                     Apple        inbox
# 3                iOS           11.4.1                     Apple          nan
# 4                iOS           11.4.1                     Apple        buyer
# ...              ...              ...                       ...          ...
# 434239       Android            8.0.0                   Samsung          gig
# 434240       Android            8.0.0                   Samsung         home
# 434241       Android            8.0.0                   Samsung     category
# 434242       Android            8.0.0                   Samsung          nan
# 434243       Android            8.0.0                   Samsung       search
#
#        channel(clean)             viewid viewaction
# 0        unattributed               home       view
# 1        unattributed         gig_detail       view
# 2        unattributed       inbox_detail       view
# 3                 NaN                nan        nan
# 4                 web  buyer_order_track       view
# ...               ...                ...        ...
# 434239         google         gig_detail       view
# 434240   unattributed               home       view
# 434241         google       category_gig       view
# 434242            NaN                nan        nan
# 434243   unattributed         search_gig       view
#
# [434244 rows x 33 columns]

# %% [markdown]
# **7. 필요하지 않은 컬럼을 버려주세요.**
#
# 여기까지 했으면 대부분의 컬럼이 잘 정리된 것 같습니다. 이제 남은 것은 필요하지 않은 컬럼을 버리고, 기존 컬럼의 이름을 직관적으로 수정하는 일들만 남았습니다. 먼저 필요하지 않은 컬럼을 제거하겠습니다. 다음의 컬럼을 데이터에서 제거해주세요.
#
# * ```osversion``` - 이제 이 컬럼을 버린 뒤 ```osversion(clean)```을 사용할 것입니다.
# * ```devicemanufacturer``` - 이제 이 컬럼을 버린 뒤 ```devicemanufacturer(clean)```을 사용할 것입니다.
# * ```canonicaldeviceuuid``` - 이제 이 컬럼을 버린 뒤 ```userid```를 사용할 것입니다.
# * ```channel``` - 이제 이 컬럼을 버린 뒤 ```channel(clean)```을 사용할 것입니다.
# * ```event_rank``` - 이 컬럼은 애초부터 사용할 필요가 없기 때문에 제거해줘도 됩니다.
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>eventcategory</th>
#             <th>isfirstactivity</th>
#             <th>apppackagename</th>
#             <th>appversion</th>
#             <th>devicetype</th>
#             <th>sourcetype</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>inappeventcategory</th>
#             <th>inappeventlabel</th>
#             <th>eventdatetime</th>
#             <th>rowuuid</th>
#             <th>isfirstgoalactivity</th>
#             <th>ostype(clean)</th>
#             <th>osversion(clean)</th>
#             <th>devicemanufacturer(clean)</th>
#             <th>userid</th>
#             <th>channel(clean)</th>
#             <th>eventdatetime_year</th>
#             <th>eventdatetime_month</th>
#             <th>eventdatetime_day</th>
#             <th>eventdatetime_hour</th>
#             <th>eventdatetime_minute</th>
#             <th>eventdatetime_second</th>
#             <th>viewid</th>
#             <th>viewaction</th>
#             <th>viewcategory</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>home.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>home</td>
#             <td>view</td>
#             <td>home</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.kmong</td>
#             <td>3.3.5</td>
#             <td>SM-N935S</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>gig_detail.view</td>
#             <td>41201.0</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>False</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>Samsung</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>gig</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>inbox_detail.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>Apple</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>inbox</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>NaN</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>NaN</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>viral</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>buyer_order_track.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>web</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>buyer</td>
#         </tr>
#     </tbody>
# </table>

# %%
# 위에서 명시한 필요하지 않은 컬럼들을 제외한 나머지를 전부 담은
# new_columns라는 이름의 리스트를 생성합니다.

new_columns = ['eventcategory', 'isfirstactivity', 'apppackagename', 'appversion',
               'devicetype', 'sourcetype', 'params_campaign', 'params_medium', 'params_term',
               'inappeventcategory', 'inappeventlabel', 'eventdatetime',
               'rowuuid', 'isfirstgoalactivity', 'ostype(clean)',
               'osversion(clean)', 'devicemanufacturer(clean)', 'userid', 'channel(clean)',
               'eventdatetime_year', 'eventdatetime_month', 'eventdatetime_day',
               'eventdatetime_hour', 'eventdatetime_minute', 'eventdatetime_second',
               'viewid', 'viewaction', 'viewcategory']

temp = temp.drop(['osversion','devicemanufacturer','channel','event_rank'],axis=1)
temp = temp[new_columns]
temp


# Write your code here!
# Out:
#        eventcategory isfirstactivity   apppackagename appversion devicetype  \
# 0               goal           False    com.kmong.iOS      4.0.4     iPhone
# 1               goal           False  com.kmong.kmong      3.3.5   SM-N935S
# 2               goal           False    com.kmong.iOS      4.0.4     iPhone
# 3         foreground             NaN    com.kmong.iOS      4.0.4     iPhone
# 4               goal           False    com.kmong.iOS      4.0.4     iPhone
# ...              ...             ...              ...        ...        ...
# 434239          goal           False  com.kmong.kmong      3.3.5   SM-G930L
# 434240          goal           False  com.kmong.kmong      3.3.5   SM-N950N
# 434241          goal           False  com.kmong.kmong      3.3.5   SM-G930L
# 434242          exit             NaN  com.kmong.kmong      3.3.5   SM-N950N
# 434243          goal           False  com.kmong.kmong      3.3.5   SM-G965N
#
#           sourcetype   params_campaign params_medium params_term  \
# 0       unattributed               NaN           NaN         NaN
# 1       unattributed               NaN           NaN         NaN
# 2       unattributed               NaN           NaN         NaN
# 3                NaN               NaN           NaN         NaN
# 4              viral               NaN           NaN         NaN
# ...              ...               ...           ...         ...
# 434239      stranger  mweb-app-install           cpc         NaN
# 434240  unattributed               NaN           NaN         NaN
# 434241      stranger  mweb-app-install           cpc         NaN
# 434242           NaN               NaN           NaN         NaN
# 434243  unattributed               NaN           NaN         NaN
#
#             inappeventcategory  inappeventlabel             eventdatetime  \
# 0                    home.view              NaN 2018-09-28 00:00:00+09:00
# 1              gig_detail.view          41201.0 2018-09-28 00:00:00+09:00
# 2            inbox_detail.view              NaN 2018-09-28 00:00:00+09:00
# 3                          NaN              NaN 2018-09-28 00:00:01+09:00
# 4       buyer_order_track.view              NaN 2018-09-28 00:00:02+09:00
# ...                        ...              ...                       ...
# 434239         gig_detail.view            104.0 2018-09-29 23:59:52+09:00
# 434240               home.view              NaN 2018-09-29 23:59:53+09:00
# 434241       category_gig.view            104.0 2018-09-29 23:59:53+09:00
# 434242                     NaN              NaN 2018-09-29 23:59:54+09:00
# 434243         search_gig.view              NaN 2018-09-29 23:59:58+09:00
#
#                                      rowuuid isfirstgoalactivity  \
# 0       fd2a188c-bc9b-4702-9c47-b546b2614817               False
# 1       e62dccef-dd70-4415-8a33-c8324ddaed38               False
# 2       14eb3197-db83-493a-b7be-83582960c40b               False
# 3       f9bb91af-248b-44dc-9f5c-1c00b37ea97b                 NaN
# 4       236e9946-7801-4898-b609-06c8ab1139dc               False
# ...                                      ...                 ...
# 434239  9d9fd3d8-30c5-49e5-8480-41b536eb4edb               False
# 434240  88653965-4aff-4d2e-8dd6-88f25ac82595               False
# 434241  40bdc87e-265a-4cc2-a1d4-f1da96a0b9dc               False
# 434242  f44a488b-1a8b-4f53-ad8e-8b21c695925b                 NaN
# 434243  5fbb87c9-4d62-4eea-a75c-cab1a3af1d52               False
#
#        ostype(clean) osversion(clean) devicemanufacturer(clean)  \
# 0                iOS           11.4.1                     Apple
# 1            Android              7.0                   Samsung
# 2                iOS             12.0                     Apple
# 3                iOS           11.4.1                     Apple
# 4                iOS           11.4.1                     Apple
# ...              ...              ...                       ...
# 434239       Android            8.0.0                   Samsung
# 434240       Android            8.0.0                   Samsung
# 434241       Android            8.0.0                   Samsung
# 434242       Android            8.0.0                   Samsung
# 434243       Android            8.0.0                   Samsung
#
#                                       userid channel(clean)  \
# 0       F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957   unattributed
# 1       8a871e50-0717-4aed-9bad-04ac3c3793be   unattributed
# 2       A9E5778A-8F3D-4597-9718-74BF953A9F64   unattributed
# 3       168761CB-CB67-4592-867D-52780D651297            NaN
# 4       ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D            web
# ...                                      ...            ...
# 434239  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3         google
# 434240  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f   unattributed
# 434241  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3         google
# 434242  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f            NaN
# 434243  965b53e9-f6d6-4a9d-827e-e60c5eb52bb8   unattributed
#
#         eventdatetime_year  eventdatetime_month  eventdatetime_day  \
# 0                     2018                    9                 28
# 1                     2018                    9                 28
# 2                     2018                    9                 28
# 3                     2018                    9                 28
# 4                     2018                    9                 28
# ...                    ...                  ...                ...
# 434239                2018                    9                 29
# 434240                2018                    9                 29
# 434241                2018                    9                 29
# 434242                2018                    9                 29
# 434243                2018                    9                 29
#
#         eventdatetime_hour  eventdatetime_minute  eventdatetime_second  \
# 0                        0                     0                     0
# 1                        0                     0                     0
# 2                        0                     0                     0
# 3                        0                     0                     1
# 4                        0                     0                     2
# ...                    ...                   ...                   ...
# 434239                  23                    59                    52
# 434240                  23                    59                    53
# 434241                  23                    59                    53
# 434242                  23                    59                    54
# 434243                  23                    59                    58
#
#                    viewid viewaction viewcategory
# 0                    home       view         home
# 1              gig_detail       view          gig
# 2            inbox_detail       view        inbox
# 3                     nan        nan          nan
# 4       buyer_order_track       view        buyer
# ...                   ...        ...          ...
# 434239         gig_detail       view          gig
# 434240               home       view         home
# 434241       category_gig       view     category
# 434242                nan        nan          nan
# 434243         search_gig       view       search
#
# [434244 rows x 28 columns]

# %% [markdown]
# **8. 이름을 통일성있게 변경해주세요.**
#
# 데이터를 분석할 때 컬럼명의 형식을 동일하게 유지하는 것이 중요합니다. 가령 회사 내부 데이터 팀에서 컬럼에서 두 개의 단어를 하이픈(-)으로 연결하기로 합의했다면 모든 컬럼을 하이픈으로 연결해야 하고, 언더바(_)로 연결하기로 합의했다면 모든 컬럼을 언더바로 연결해야 합니다.
#
# 하지만 아쉽게도, 현재 데이터의 컬럼명에는 이런 통일성이 잘 갖춰져 있는 것 같습니다. (ex: ```eventcategory``` vs ```params_term```) 그러므로 데이터의 컬럼명을 작성하는 형식을 하나로 통일하도록 하겠습니다. 이번 데이터에서 컬럼명을 짓는 방식은 다음과 같습니다.
#
#   * 단어와 단어 사이는 언제나 언더바(_)로 구분합니다. 가령 하이픈(-)으로 구분하거나, 띄어쓰기를 사용하면 안 됩니다. (ex: event_category는 허용하지만, eventcategory나 event-category, 또는 event category는 허용하지 않습니다)
#   * 컬럼명에 (clean)이라고 들어간 표현은 이제는 지워줘도 될 것 같습니다. (ex channel(clean) -> channel)
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>event_category</th>
#             <th>is_first_activity</th>
#             <th>app_package_name</th>
#             <th>app_version</th>
#             <th>device_type</th>
#             <th>source_type</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>in_app_event_category</th>
#             <th>in_app_event_label</th>
#             <th>event_datetime</th>
#             <th>row_uuid</th>
#             <th>is_first_goal_activity</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>device_manufacturer</th>
#             <th>user_id</th>
#             <th>channel</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>view_category</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>home.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>home</td>
#             <td>view</td>
#             <td>home</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.kmong</td>
#             <td>3.3.5</td>
#             <td>SM-N935S</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>gig_detail.view</td>
#             <td>41201.0</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>False</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>Samsung</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>gig</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>inbox_detail.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>Apple</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>unattributed</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>inbox</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>NaN</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>NaN</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>goal</td>
#             <td>False</td>
#             <td>com.kmong.iOS</td>
#             <td>4.0.4</td>
#             <td>iPhone</td>
#             <td>viral</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>buyer_order_track.view</td>
#             <td>NaN</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>False</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>Apple</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>web</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>buyer</td>
#         </tr>
#     </tbody>
# </table>

# %%
# 위에서 명시한 형식에 맞게 컬럼명을 새롭게 변경합니다.
# 이를 new_columns라는 이름의 변수에 파이썬 리스트로 집어넣습니다.
new_columns = ['event_category', 'is_first_activity', 'app_package_name', 'app_version',
               'device_type', 'source_type', 'params_campaign', 'params_medium', 'params_term',
               'in_app_event_category', 'in_app_event_label', 'event_datetime',
               'row_uuid', 'is_first_goal_activity', 'os_type',
               'os_version', 'device_manufacturer', 'user_id', 'channel',
               'event_datetime_year', 'event_datetime_month', 'event_datetime_day',
               'event_datetime_hour', 'event_datetime_minute', 'event_datetime_second',
               'view_id', 'view_action', 'view_category']

temp.columns=new_columns
temp.head()
# len(new_columns)
# temp.info()
# Write your code here!
# Out:
#   event_category is_first_activity app_package_name app_version device_type  \
# 0           goal             False    com.kmong.iOS       4.0.4      iPhone
# 1           goal             False  com.kmong.kmong       3.3.5    SM-N935S
# 2           goal             False    com.kmong.iOS       4.0.4      iPhone
# 3     foreground               NaN    com.kmong.iOS       4.0.4      iPhone
# 4           goal             False    com.kmong.iOS       4.0.4      iPhone
#
#     source_type params_campaign params_medium params_term  \
# 0  unattributed             NaN           NaN         NaN
# 1  unattributed             NaN           NaN         NaN
# 2  unattributed             NaN           NaN         NaN
# 3           NaN             NaN           NaN         NaN
# 4         viral             NaN           NaN         NaN
#
#     in_app_event_category  in_app_event_label            event_datetime  \
# 0               home.view                 NaN 2018-09-28 00:00:00+09:00
# 1         gig_detail.view             41201.0 2018-09-28 00:00:00+09:00
# 2       inbox_detail.view                 NaN 2018-09-28 00:00:00+09:00
# 3                     NaN                 NaN 2018-09-28 00:00:01+09:00
# 4  buyer_order_track.view                 NaN 2018-09-28 00:00:02+09:00
#
#                                row_uuid is_first_goal_activity  os_type  \
# 0  fd2a188c-bc9b-4702-9c47-b546b2614817                  False      iOS
# 1  e62dccef-dd70-4415-8a33-c8324ddaed38                  False  Android
# 2  14eb3197-db83-493a-b7be-83582960c40b                  False      iOS
# 3  f9bb91af-248b-44dc-9f5c-1c00b37ea97b                    NaN      iOS
# 4  236e9946-7801-4898-b609-06c8ab1139dc                  False      iOS
#
#   os_version device_manufacturer                               user_id  \
# 0     11.4.1               Apple  F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957
# 1        7.0             Samsung  8a871e50-0717-4aed-9bad-04ac3c3793be
# 2       12.0               Apple  A9E5778A-8F3D-4597-9718-74BF953A9F64
# 3     11.4.1               Apple  168761CB-CB67-4592-867D-52780D651297
# 4     11.4.1               Apple  ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D
#
#         channel  event_datetime_year  event_datetime_month  \
# 0  unattributed                 2018                     9
# 1  unattributed                 2018                     9
# 2  unattributed                 2018                     9
# 3           NaN                 2018                     9
# 4           web                 2018                     9
#
#    event_datetime_day  event_datetime_hour  event_datetime_minute  \
# 0                  28                    0                      0
# 1                  28                    0                      0
# 2                  28                    0                      0
# 3                  28                    0                      0
# 4                  28                    0                      0
#
#    event_datetime_second            view_id view_action view_category
# 0                      0               home        view          home
# 1                      0         gig_detail        view           gig
# 2                      0       inbox_detail        view         inbox
# 3                      1                nan         nan           nan
# 4                      2  buyer_order_track        view         buyer

# %% [markdown]
# **9. 컬럼을 정렬해주세요.**
#
# 마지막은 컬럼을 용도에 맞게 잘 정렬해주면 될 것 같습니다. 정렬할 때는 보통 1) 중요한 컬럼을 좌측으로, 상대적으로 중요하지 않은 컬럼을 우측으로 옮겨주고, 2) 비슷한 역할을 하는 컬럼이나 서로간에 연관되어있는 컬럼은 같은 위치로 묶어줍니다. 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>row_uuid</th>
#             <th>app_package_name</th>
#             <th>user_id</th>
#             <th>event_datetime</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>device_manufacturer</th>
#             <th>device_type</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>app_version</th>
#             <th>event_category</th>
#             <th>view_category</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>in_app_event_category</th>
#             <th>in_app_event_label</th>
#             <th>source_type</th>
#             <th>channel</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>is_first_activity</th>
#             <th>is_first_goal_activity</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>com.kmong.iOS</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#             <td>home.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>com.kmong.kmong</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Samsung</td>
#             <td>SM-N935S</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>3.3.5</td>
#             <td>goal</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>gig_detail.view</td>
#             <td>41201.0</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>com.kmong.iOS</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>inbox_detail.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>com.kmong.iOS</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>com.kmong.iOS</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>buyer_order_track.view</td>
#             <td>NaN</td>
#             <td>viral</td>
#             <td>web</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#     </tbody>
# </table>

# %%
# 위에서 명시한 형식에 맞게 컬럼의 순서를 변경합니다.
# 이를 oredered_columns라는 이름의 변수에 파이썬 리스트로 집어넣습니다.
oredered_columns = ['row_uuid', 'app_package_name', 'user_id',
                    'event_datetime', 'event_datetime_year', 'event_datetime_month', 'event_datetime_day',
                    'event_datetime_hour', 'event_datetime_minute', 'event_datetime_second',
                    'device_manufacturer', 'device_type', 'os_type', 'os_version', 'app_version',
                    'event_category', 'view_category', 'view_id', 'view_action',
                    'in_app_event_category', 'in_app_event_label', 
                    'source_type', 'channel', 'params_campaign', 'params_medium', 'params_term',
                    'is_first_activity', 'is_first_goal_activity']

temp = temp[oredered_columns]
temp

# Write your code here!
# Out:
#                                     row_uuid app_package_name  \
# 0       fd2a188c-bc9b-4702-9c47-b546b2614817    com.kmong.iOS
# 1       e62dccef-dd70-4415-8a33-c8324ddaed38  com.kmong.kmong
# 2       14eb3197-db83-493a-b7be-83582960c40b    com.kmong.iOS
# 3       f9bb91af-248b-44dc-9f5c-1c00b37ea97b    com.kmong.iOS
# 4       236e9946-7801-4898-b609-06c8ab1139dc    com.kmong.iOS
# ...                                      ...              ...
# 434239  9d9fd3d8-30c5-49e5-8480-41b536eb4edb  com.kmong.kmong
# 434240  88653965-4aff-4d2e-8dd6-88f25ac82595  com.kmong.kmong
# 434241  40bdc87e-265a-4cc2-a1d4-f1da96a0b9dc  com.kmong.kmong
# 434242  f44a488b-1a8b-4f53-ad8e-8b21c695925b  com.kmong.kmong
# 434243  5fbb87c9-4d62-4eea-a75c-cab1a3af1d52  com.kmong.kmong
#
#                                      user_id            event_datetime  \
# 0       F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957 2018-09-28 00:00:00+09:00
# 1       8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:00+09:00
# 2       A9E5778A-8F3D-4597-9718-74BF953A9F64 2018-09-28 00:00:00+09:00
# 3       168761CB-CB67-4592-867D-52780D651297 2018-09-28 00:00:01+09:00
# 4       ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D 2018-09-28 00:00:02+09:00
# ...                                      ...                       ...
# 434239  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3 2018-09-29 23:59:52+09:00
# 434240  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f 2018-09-29 23:59:53+09:00
# 434241  1fbc9ad2-8109-4294-ae9e-9acf6dce72c3 2018-09-29 23:59:53+09:00
# 434242  ea69fbd8-16fe-4db4-ae1e-512d5bbd1d6f 2018-09-29 23:59:54+09:00
# 434243  965b53e9-f6d6-4a9d-827e-e60c5eb52bb8 2018-09-29 23:59:58+09:00
#
#         event_datetime_year  event_datetime_month  event_datetime_day  \
# 0                      2018                     9                  28
# 1                      2018                     9                  28
# 2                      2018                     9                  28
# 3                      2018                     9                  28
# 4                      2018                     9                  28
# ...                     ...                   ...                 ...
# 434239                 2018                     9                  29
# 434240                 2018                     9                  29
# 434241                 2018                     9                  29
# 434242                 2018                     9                  29
# 434243                 2018                     9                  29
#
#         event_datetime_hour  event_datetime_minute  event_datetime_second  \
# 0                         0                      0                      0
# 1                         0                      0                      0
# 2                         0                      0                      0
# 3                         0                      0                      1
# 4                         0                      0                      2
# ...                     ...                    ...                    ...
# 434239                   23                     59                     52
# 434240                   23                     59                     53
# 434241                   23                     59                     53
# 434242                   23                     59                     54
# 434243                   23                     59                     58
#
#        device_manufacturer device_type  os_type os_version app_version  \
# 0                    Apple      iPhone      iOS     11.4.1       4.0.4
# 1                  Samsung    SM-N935S  Android        7.0       3.3.5
# 2                    Apple      iPhone      iOS       12.0       4.0.4
# 3                    Apple      iPhone      iOS     11.4.1       4.0.4
# 4                    Apple      iPhone      iOS     11.4.1       4.0.4
# ...                    ...         ...      ...        ...         ...
# 434239             Samsung    SM-G930L  Android      8.0.0       3.3.5
# 434240             Samsung    SM-N950N  Android      8.0.0       3.3.5
# 434241             Samsung    SM-G930L  Android      8.0.0       3.3.5
# 434242             Samsung    SM-N950N  Android      8.0.0       3.3.5
# 434243             Samsung    SM-G965N  Android      8.0.0       3.3.5
#
#        event_category view_category            view_id view_action  \
# 0                goal          home               home        view
# 1                goal           gig         gig_detail        view
# 2                goal         inbox       inbox_detail        view
# 3          foreground           nan                nan         nan
# 4                goal         buyer  buyer_order_track        view
# ...               ...           ...                ...         ...
# 434239           goal           gig         gig_detail        view
# 434240           goal          home               home        view
# 434241           goal      category       category_gig        view
# 434242           exit           nan                nan         nan
# 434243           goal        search         search_gig        view
#
#          in_app_event_category  in_app_event_label   source_type  \
# 0                    home.view                 NaN  unattributed
# 1              gig_detail.view             41201.0  unattributed
# 2            inbox_detail.view                 NaN  unattributed
# 3                          NaN                 NaN           NaN
# 4       buyer_order_track.view                 NaN         viral
# ...                        ...                 ...           ...
# 434239         gig_detail.view               104.0      stranger
# 434240               home.view                 NaN  unattributed
# 434241       category_gig.view               104.0      stranger
# 434242                     NaN                 NaN           NaN
# 434243         search_gig.view                 NaN  unattributed
#
#              channel   params_campaign params_medium params_term  \
# 0       unattributed               NaN           NaN         NaN
# 1       unattributed               NaN           NaN         NaN
# 2       unattributed               NaN           NaN         NaN
# 3                NaN               NaN           NaN         NaN
# 4                web               NaN           NaN         NaN
# ...              ...               ...           ...         ...
# 434239        google  mweb-app-install           cpc         NaN
# 434240  unattributed               NaN           NaN         NaN
# 434241        google  mweb-app-install           cpc         NaN
# 434242           NaN               NaN           NaN         NaN
# 434243  unattributed               NaN           NaN         NaN
#
#        is_first_activity is_first_goal_activity
# 0                  False                  False
# 1                  False                  False
# 2                  False                  False
# 3                    NaN                    NaN
# 4                  False                  False
# ...                  ...                    ...
# 434239             False                  False
# 434240             False                  False
# 434241             False                  False
# 434242               NaN                    NaN
# 434243             False                  False
#
# [434244 rows x 28 columns]

# %% [markdown]
# **10. funnel 데이터를 정리해주세요.**
#
# 다음으로는 퍼널(funnel) 데이터를 정리하겠습니다. 퍼널 데이터에는 크몽 서비스에서 사용하는 퍼널에 대한 부연 설명을 담고 있습니다. 기쁘게도 이 데이터는 잘 정리되어 있기 때문에, 별도로 처리해줘야 하는 건 많지 않습니다. 다음의 설명을 참고하여 데이터를 정리해주세요.
#
#   1. 먼저 컬럼을 ```Lv1```, ```Lv2```, ```viewid```, ```viewid desc```, ```funnel name```, ```funnel desc``` 순으로 정렬해주세요.
#   2. 그 다음 모든 컬럼을 소문자로 통일하고(ex: Lv1 -> lv1), 띄어쓰기를 언더바(_)로 바꿔주세요. (ex: funnel name -> funnel_name)
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>lv1</th>
#             <th>lv2</th>
#             <th>view_id</th>
#             <th>view_desc</th>
#             <th>funnel_name</th>
#             <th>funnel_desc</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>11</td>
#             <td>1100</td>
#             <td>home</td>
#             <td>홈 (탭)</td>
#             <td>home</td>
#             <td>홈</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>12</td>
#             <td>1210</td>
#             <td>category_list</td>
#             <td>카테고리 목록 (탭)</td>
#             <td>category</td>
#             <td>카테고리</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>12</td>
#             <td>1200</td>
#             <td>category_gig</td>
#             <td>카테고리-상품목록</td>
#             <td>category</td>
#             <td>카테고리</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>13</td>
#             <td>1300</td>
#             <td>search</td>
#             <td>검색</td>
#             <td>search</td>
#             <td>검색</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>13</td>
#             <td>1301</td>
#             <td>search_gig</td>
#             <td>검색-상품목록</td>
#             <td>search</td>
#             <td>검색</td>
#         </tr>
#     </tbody>
# </table>

# %%
# Write your code here!
temp_funnel = raw_funnel
temp_funnel = temp_funnel[['Lv1','Lv2','viewid','viewid desc','funnel name', 'funnel desc']]
temp_funnel.columns = ['lv1','lv2','view_id','view_desc','funnel_name','funnel_desc']
temp_funnel.head(5)
# Out:
#    lv1   lv2        view_id    view_desc funnel_name funnel_desc
# 0   11  1100           home        홈 (탭)        home           홈
# 1   12  1210  category_list  카테고리 목록 (탭)    category        카테고리
# 2   12  1200   category_gig    카테고리-상품목록    category        카테고리
# 3   13  1300         search           검색      search          검색
# 4   13  1301     search_gig      검색-상품목록      search          검색

# %% [markdown]
# **11. category 데이터를 정리해주세요.**
#
# 퍼널(funnel) 데이터와 마찬가지로, category 데이터도 정리하겠습니다. category 데이터는크몽에서 판매하는 상품의 카테고리를 나타내는 정보인데, 퍼널 데이터와 마찬가지로 이 데이터로 잘 정리되어 있기 때문에 크게 건드려줘야 하는 부분은 없고, 컬럼명만 바꿔주면 될 것 같습니다. 다음의 기준을 참고하여 컬럼명을 사정해주세요.
#
# * 단어 사이에는 언더바(```_```)를 붙입니다. (ex: categoryid -> category_id)
# * 축약어는 전체 단어로 풀어서 작성합니다. (ex: cat1 -> category1)
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>depth</th>
#             <th>category_id</th>
#             <th>category_name</th>
#             <th>category1_id</th>
#             <th>category2_id</th>
#             <th>category3_id</th>
#             <th>category1</th>
#             <th>category2</th>
#             <th>category3</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>1</td>
#             <td>1</td>
#             <td>디자인</td>
#             <td>1</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>디자인</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>1</td>
#             <td>2</td>
#             <td>마케팅</td>
#             <td>2</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>마케팅</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>1</td>
#             <td>3</td>
#             <td>번역·통역</td>
#             <td>3</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>번역·통역</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>1</td>
#             <td>4</td>
#             <td>문서작성</td>
#             <td>4</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>문서작성</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>1</td>
#             <td>6</td>
#             <td>IT·프로그래밍</td>
#             <td>6</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>IT·프로그래밍</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#     </tbody>
# </table>

# %%
# Write your code here!
temp_category = raw_category
temp_category.columns = ['depth','category_id','category_name','category1_id','category2_id','category3_id','category1','category2','category3']
temp_category.head(5)
# Out:
#    depth  category_id category_name  category1_id  category2_id  category3_id  \
# 0      1            1           디자인             1           NaN           NaN
# 1      1            2           마케팅             2           NaN           NaN
# 2      1            3         번역·통역             3           NaN           NaN
# 3      1            4          문서작성             4           NaN           NaN
# 4      1            6      IT·프로그래밍             6           NaN           NaN
#
#   category1 category2 category3
# 0       디자인       NaN       NaN
# 1       마케팅       NaN       NaN
# 2     번역·통역       NaN       NaN
# 3      문서작성       NaN       NaN
# 4  IT·프로그래밍       NaN       NaN

# %% [markdown]
# ### 세 개의 데이터를 하나로 합치기
#
# 이번에는 수정한 ```log```, ```funnel```, ```category``` 데이터를 하나로 합쳐보겠습니다. 이 부분은 다소 난이도가 높기 때문에, 적극적으로 구글을 검색하거나 다른 자료를 참고하는 것을 추천드립니다. 특히나 [Merge, join, and concatenate](https://pandas.pydata.org/pandas-docs/stable/merging.html) 자료를 한 번 살펴보신 뒤 아래 문제를 시도한다면 더 쉽게 문제를 풀 수 있을 것입니다.

# %% [markdown]
# **12. ```log``` 데이터의 view_id 컬럼과 ```funnel``` 데이터의 view_id 컬럼을 활용하여 두 개의 데이터를 합쳐주세요**
#
# 앞서 설명드린대로 ```log``` 데이터에 사용자의 액티비티가 모두 모여져있고, 여기에서 가장 중요한 정보 중 하나인 퍼널(funnel)에 대한 부연 설명이 ```funnel``` 데이터에 모여 있습니다. 그러므로 이 두개를 합친다면, 차후에 ```log```데이터에서 퍼널 분석을 할 때 다른 데이터 분석가들이 더 직관적으로 데이터를 이해할 수 있을 것 같습니다.
#
# 그러므로 두 개의 데이터를 합쳐주세요. 두 개의 데이터와 연관이 있는 컬럼은 ```view_id```라는 이름의 컬럼이며, 데이터를 합칠 때는 [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html)라는 함수를 잘 사용하면 생각보다 쉽게 데이터를 합칠 수 있습니다. 또한 합칠 때 ```log``` 데이터는 누락되지 않고 전부 살아있어야 하며, ```funnel```데이터는 ```log```데이터에 일치하는 것만 살리고 나머지는 지워져도 상관 없습니다. (이를 전문 용어로 **left merge**라고 합니다)
#
# 최종적으로는 다음의 결과가 나와야 합니다. (```log``` 데이터와 동일해보이지만 자세히 보시면 오른쪽에 ```funnel``` 데이터가 추가되어 있습니다)

# %% [markdown]
# <table border="1" class="dataframe">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>row_uuid</th>
#             <th>app_package_name</th>
#             <th>user_id</th>
#             <th>event_datetime</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>device_manufacturer</th>
#             <th>device_type</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>app_version</th>
#             <th>event_category</th>
#             <th>view_category</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>in_app_event_category</th>
#             <th>in_app_event_label</th>
#             <th>source_type</th>
#             <th>channel</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>is_first_activity</th>
#             <th>is_first_goal_activity</th>
#             <th>lv1</th>
#             <th>lv2</th>
#             <th>view_desc</th>
#             <th>funnel_name</th>
#             <th>funnel_desc</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>com.kmong.iOS</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#             <td>home.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>11.0</td>
#             <td>1100.0</td>
#             <td>홈 (탭)</td>
#             <td>home</td>
#             <td>홈</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>com.kmong.kmong</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Samsung</td>
#             <td>SM-N935S</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>3.3.5</td>
#             <td>goal</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>gig_detail.view</td>
#             <td>41201.0</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>14.0</td>
#             <td>1400.0</td>
#             <td>상품상세</td>
#             <td>gig</td>
#             <td>상품</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>com.kmong.iOS</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>inbox_detail.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>16.0</td>
#             <td>1610.0</td>
#             <td>메시지목록-상세</td>
#             <td>inbox</td>
#             <td>메시지</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>com.kmong.iOS</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>com.kmong.iOS</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>buyer_order_track.view</td>
#             <td>NaN</td>
#             <td>viral</td>
#             <td>web</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>24.0</td>
#             <td>2410.0</td>
#             <td>메뉴목록-구매관리-거래메시지</td>
#             <td>transaction_history</td>
#             <td>거래관리</td>
#         </tr>
#     </tbody>
# </table>

# %%
# Write your code here!
merge_data = ''
temp['view_id'].head(5)
temp_funnel['view_id'].head(5)

merge_data = temp.merge(temp_funnel,left_on='view_id',right_on='view_id')
merge_data
# Out:
#                                     row_uuid app_package_name  \
# 0       fd2a188c-bc9b-4702-9c47-b546b2614817    com.kmong.iOS
# 1       db8ce65f-3707-4c1b-8361-51bcb9d4ecd9  com.kmong.kmong
# 2       ff3f2e83-13ea-46af-a500-73811ed4ecc9  com.kmong.kmong
# 3       91742336-3566-4be9-bee7-6e04cee7cae7  com.kmong.kmong
# 4       8e75d85f-4b94-4301-9cee-ba14bebd1280  com.kmong.kmong
# ...                                      ...              ...
# 304545  b7ecede1-c469-48d0-8b4a-6fb8a9ce7760    com.kmong.iOS
# 304546  b888db54-a880-4a43-ad39-257ba533b196    com.kmong.iOS
# 304547  9baeed3c-9026-4b9f-aa0c-0b34d41c0164  com.kmong.kmong
# 304548  597dc85e-9b87-4afb-a275-716fb3daa6cc    com.kmong.iOS
# 304549  ea5031da-3e96-4fa9-9322-b2659de82e03  com.kmong.kmong
#
#                                      user_id            event_datetime  \
# 0       F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957 2018-09-28 00:00:00+09:00
# 1       6d1ea29b-5d5d-4c33-b2cf-7c68b41ce638 2018-09-28 00:00:02+09:00
# 2       0e5dec96-3f73-4542-b6b6-2031fb2171ad 2018-09-28 00:00:03+09:00
# 3       a3b89a23-034a-4f4c-8414-adda3dc711cd 2018-09-28 00:00:10+09:00
# 4       1a2f843c-759b-4bab-a368-751d76f2c4e8 2018-09-28 00:00:11+09:00
# ...                                      ...                       ...
# 304545  06C32753-7678-4E34-AC3F-625FA7B5D115 2018-09-29 15:19:19+09:00
# 304546  06C32753-7678-4E34-AC3F-625FA7B5D115 2018-09-29 15:20:05+09:00
# 304547  3adb3f17-5982-42ab-9fc9-12681ab1e75a 2018-09-29 15:37:18+09:00
# 304548  BC7DE6C9-03E6-44C7-B5AA-68799BB9786B 2018-09-29 20:42:14+09:00
# 304549  13bd2fdb-ecfb-4995-8737-ec1f5329d10f 2018-09-29 21:09:31+09:00
#
#         event_datetime_year  event_datetime_month  event_datetime_day  \
# 0                      2018                     9                  28
# 1                      2018                     9                  28
# 2                      2018                     9                  28
# 3                      2018                     9                  28
# 4                      2018                     9                  28
# ...                     ...                   ...                 ...
# 304545                 2018                     9                  29
# 304546                 2018                     9                  29
# 304547                 2018                     9                  29
# 304548                 2018                     9                  29
# 304549                 2018                     9                  29
#
#         event_datetime_hour  event_datetime_minute  event_datetime_second  \
# 0                         0                      0                      0
# 1                         0                      0                      2
# 2                         0                      0                      3
# 3                         0                      0                     10
# 4                         0                      0                     11
# ...                     ...                    ...                    ...
# 304545                   15                     19                     19
# 304546                   15                     20                      5
# 304547                   15                     37                     18
# 304548                   20                     42                     14
# 304549                   21                      9                     31
#
#        device_manufacturer device_type  os_type os_version app_version  \
# 0                    Apple      iPhone      iOS     11.4.1       4.0.4
# 1                  Samsung    SM-G955N  Android      8.0.0       3.3.5
# 2                  Samsung    SM-A530N  Android      7.1.1       3.3.3
# 3                  Samsung    SM-G930S  Android      8.0.0       3.3.5
# 4                       LG    LG-F800S  Android      8.0.0       3.3.5
# ...                    ...         ...      ...        ...         ...
# 304545               Apple      iPhone      iOS     11.4.1       4.0.4
# 304546               Apple      iPhone      iOS     11.4.1       4.0.4
# 304547             Samsung    SM-N950N  Android      8.0.0       3.3.2
# 304548               Apple      iPhone      iOS     11.4.1       4.0.4
# 304549             Samsung    SM-G965N  Android      8.0.0       3.3.3
#
#        event_category view_category                          view_id  \
# 0                goal          home                             home
# 1                goal          home                             home
# 2                goal          home                             home
# 3                goal          home                             home
# 4                goal          home                             home
# ...               ...           ...                              ...
# 304545           goal     kmongCash  kmongCash_history_refundRequest
# 304546           goal     kmongCash  kmongCash_history_refundRequest
# 304547           goal     kmongCash  kmongCash_history_refundRequest
# 304548           goal     kmongCash  kmongCash_history_refundRequest
# 304549           goal     kmongCash  kmongCash_history_refundRequest
#
#        view_action                  in_app_event_category  in_app_event_label  \
# 0             view                              home.view                 NaN
# 1             view                              home.view                 NaN
# 2             view                              home.view                 NaN
# 3             view                              home.view                 NaN
# 4             view                              home.view                 NaN
# ...            ...                                    ...                 ...
# 304545       click  kmongCash_history_refundRequest.click                 NaN
# 304546       click  kmongCash_history_refundRequest.click                 NaN
# 304547       click  kmongCash_history_refundRequest.click                 NaN
# 304548       click  kmongCash_history_refundRequest.click                 NaN
# 304549       click  kmongCash_history_refundRequest.click                 NaN
#
#          source_type       channel params_campaign params_medium params_term  \
# 0       unattributed  unattributed             NaN           NaN         NaN
# 1       unattributed  unattributed             NaN           NaN         NaN
# 2       unattributed  unattributed             NaN           NaN         NaN
# 3       unattributed  unattributed             NaN           NaN         NaN
# 4         app-market        google             NaN       organic         NaN
# ...              ...           ...             ...           ...         ...
# 304545  unattributed  unattributed             NaN           NaN         NaN
# 304546  unattributed  unattributed             NaN           NaN         NaN
# 304547  unattributed  unattributed             NaN           NaN         NaN
# 304548         viral           web             NaN           NaN         NaN
# 304549  unattributed  unattributed             NaN           NaN         NaN
#
#        is_first_activity is_first_goal_activity  lv1   lv2       view_desc  \
# 0                  False                  False   11  1100           홈 (탭)
# 1                  False                  False   11  1100           홈 (탭)
# 2                  False                  False   11  1100           홈 (탭)
# 3                  False                  False   11  1100           홈 (탭)
# 4                  False                  False   11  1100           홈 (탭)
# ...                  ...                    ...  ...   ...             ...
# 304545             False                  False   24  2452  메뉴목록-크몽캐시-캐시환불
# 304546             False                  False   24  2452  메뉴목록-크몽캐시-캐시환불
# 304547             False                  False   24  2452  메뉴목록-크몽캐시-캐시환불
# 304548              True                   True   24  2452  메뉴목록-크몽캐시-캐시환불
# 304549              True                   True   24  2452  메뉴목록-크몽캐시-캐시환불
#
#                 funnel_name funnel_desc
# 0                      home           홈
# 1                      home           홈
# 2                      home           홈
# 3                      home           홈
# 4                      home           홈
# ...                     ...         ...
# 304545  transaction_history        거래관리
# 304546  transaction_history        거래관리
# 304547  transaction_history        거래관리
# 304548  transaction_history        거래관리
# 304549  transaction_history        거래관리
#
# [304550 rows x 33 columns]

# %% [markdown]
# **13. 12번 데이터의 ```in_app_event_label``` 컬럼과 ```category``` 데이터의 ```category_id``` 컬럼을 활용하여 두 개의 데이터를 합쳐주세요.**
#
# 퍼널(funnel)과 마찬가지로 ```category``` 데이터도 하나로 합쳐보겠습니다.
#
# 이것도 12번 데이터와 마찬가지로 판다스(Pandas)의 [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html), 그것도 **left merge**를 사용하면 됩니다. 다만 두 데이터가 ```view_id```라는 공통의 컬럼을 보유하고 있던 이전과는 다르게, 이번에는 12번 데이터에는 ```in_app_event_label``` 컬럼이, ```category``` 데이터에는 ```category_id``` 컬럼이 서로 연관이 있습니다. 이 컬럼을 사용하여 두 개를 합쳐주세요.
#
# 최종적으로는 다음의 결과가 나와야 합니다. (자세히 보시면 오른쪽에 ```category_id``` 데이터가 추가되어 있습니다)

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>row_uuid</th>
#             <th>app_package_name</th>
#             <th>user_id</th>
#             <th>event_datetime</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>device_manufacturer</th>
#             <th>device_type</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>app_version</th>
#             <th>event_category</th>
#             <th>view_category</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>in_app_event_category</th>
#             <th>in_app_event_label</th>
#             <th>source_type</th>
#             <th>channel</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>is_first_activity</th>
#             <th>is_first_goal_activity</th>
#             <th>lv1</th>
#             <th>lv2</th>
#             <th>view_desc</th>
#             <th>funnel_name</th>
#             <th>funnel_desc</th>
#             <th>depth</th>
#             <th>category_id</th>
#             <th>category_name</th>
#             <th>category1_id</th>
#             <th>category2_id</th>
#             <th>category3_id</th>
#             <th>category1</th>
#             <th>category2</th>
#             <th>category3</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>com.kmong.iOS</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#             <td>home.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>11.0</td>
#             <td>1100.0</td>
#             <td>홈 (탭)</td>
#             <td>home</td>
#             <td>홈</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>com.kmong.kmong</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Samsung</td>
#             <td>SM-N935S</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>3.3.5</td>
#             <td>goal</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>gig_detail.view</td>
#             <td>41201.0</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>14.0</td>
#             <td>1400.0</td>
#             <td>상품상세</td>
#             <td>gig</td>
#             <td>상품</td>
#             <td>3.0</td>
#             <td>41201.0</td>
#             <td>자기소개서</td>
#             <td>4.0</td>
#             <td>412.0</td>
#             <td>41201.0</td>
#             <td>문서작성</td>
#             <td>자기소개서·이력서</td>
#             <td>자기소개서</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>com.kmong.iOS</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>inbox_detail.view</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>16.0</td>
#             <td>1610.0</td>
#             <td>메시지목록-상세</td>
#             <td>inbox</td>
#             <td>메시지</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>com.kmong.iOS</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>com.kmong.iOS</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>buyer_order_track.view</td>
#             <td>NaN</td>
#             <td>viral</td>
#             <td>web</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#             <td>24.0</td>
#             <td>2410.0</td>
#             <td>메뉴목록-구매관리-거래메시지</td>
#             <td>transaction_history</td>
#             <td>거래관리</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#     </tbody>
# </table>

# %%
# Write your code here!

merge_data = merge_data.merge(temp_category, left_on='in_app_event_label', right_on='category_id')
merge_data
# Out:
#                                    row_uuid app_package_name  \
# 0      e62dccef-dd70-4415-8a33-c8324ddaed38  com.kmong.kmong
# 1      a6d462c3-d4a3-4a2c-8942-88f2cae0012e  com.kmong.kmong
# 2      7d06d33e-cd1f-4064-a3d3-cb947424ff97  com.kmong.kmong
# 3      497ae46f-6749-4094-853f-d5b0b33e18fc  com.kmong.kmong
# 4      291c4d91-86c2-4102-b6c9-070bee255a4d  com.kmong.kmong
# ...                                     ...              ...
# 60829  180a016e-db8d-4c65-a676-dd3621ac444a  com.kmong.kmong
# 60830  4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013  com.kmong.kmong
# 60831  7868ecf3-0a2a-4ca6-a538-a898f1638bfe  com.kmong.kmong
# 60832  3e2d3015-bbf8-45a9-b2ca-c99e722dfba3  com.kmong.kmong
# 60833  5df94f15-09cd-4f3e-81fb-5957320a5c80  com.kmong.kmong
#
#                                     user_id            event_datetime  \
# 0      8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:00+09:00
# 1      8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:02+09:00
# 2      8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:03+09:00
# 3      8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:06+09:00
# 4      8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:28+09:00
# ...                                     ...                       ...
# 60829  7f345e9b-fa52-4a9c-9691-2986091bc264 2018-09-29 15:01:12+09:00
# 60830  8621f34b-ae3c-4c92-9b1d-b6187048a693 2018-09-29 16:35:58+09:00
# 60831  2a67e931-055c-4798-81f3-c87aad419284 2018-09-29 19:45:58+09:00
# 60832  fc5b560c-20aa-470a-a3da-e92177d16bc5 2018-09-29 20:50:35+09:00
# 60833  fc5b560c-20aa-470a-a3da-e92177d16bc5 2018-09-29 20:51:08+09:00
#
#        event_datetime_year  event_datetime_month  event_datetime_day  \
# 0                     2018                     9                  28
# 1                     2018                     9                  28
# 2                     2018                     9                  28
# 3                     2018                     9                  28
# 4                     2018                     9                  28
# ...                    ...                   ...                 ...
# 60829                 2018                     9                  29
# 60830                 2018                     9                  29
# 60831                 2018                     9                  29
# 60832                 2018                     9                  29
# 60833                 2018                     9                  29
#
#        event_datetime_hour  event_datetime_minute  event_datetime_second  \
# 0                        0                      0                      0
# 1                        0                      0                      2
# 2                        0                      0                      3
# 3                        0                      0                      6
# 4                        0                      0                     28
# ...                    ...                    ...                    ...
# 60829                   15                      1                     12
# 60830                   16                     35                     58
# 60831                   19                     45                     58
# 60832                   20                     50                     35
# 60833                   20                     51                      8
#
#       device_manufacturer device_type  os_type os_version app_version  \
# 0                 Samsung    SM-N935S  Android        7.0       3.3.5
# 1                 Samsung    SM-N935S  Android        7.0       3.3.5
# 2                 Samsung    SM-N935S  Android        7.0       3.3.5
# 3                 Samsung    SM-N935S  Android        7.0       3.3.5
# 4                 Samsung    SM-N935S  Android        7.0       3.3.5
# ...                   ...         ...      ...        ...         ...
# 60829                  LG   LGM-V300S  Android      8.0.0       3.3.5
# 60830             Samsung    SM-G930K  Android        7.0       3.3.5
# 60831             Samsung    SM-N960N  Android      8.1.0       3.3.5
# 60832             Samsung    SM-G930S  Android      8.0.0       3.3.5
# 60833             Samsung    SM-G930S  Android      8.0.0       3.3.5
#
#       event_category view_category       view_id view_action  \
# 0               goal           gig    gig_detail        view
# 1               goal           gig    gig_detail        view
# 2               goal           gig    gig_detail        view
# 3               goal           gig    gig_detail        view
# 4               goal           gig    gig_detail        view
# ...              ...           ...           ...         ...
# 60829           goal      category  category_gig        view
# 60830           goal      category  category_gig        view
# 60831           goal      category  category_gig        view
# 60832           goal      category  category_gig        view
# 60833           goal      category  category_gig        view
#
#       in_app_event_category  in_app_event_label   source_type       channel  \
# 0           gig_detail.view             41201.0  unattributed  unattributed
# 1           gig_detail.view             41201.0  unattributed  unattributed
# 2           gig_detail.view             41201.0  unattributed  unattributed
# 3           gig_detail.view             41201.0  unattributed  unattributed
# 4           gig_detail.view             41201.0  unattributed  unattributed
# ...                     ...                 ...           ...           ...
# 60829     category_gig.view               612.0  unattributed  unattributed
# 60830     category_gig.view               612.0  unattributed  unattributed
# 60831     category_gig.view               612.0  unattributed  unattributed
# 60832     category_gig.view               612.0  unattributed  unattributed
# 60833     category_gig.view               612.0  unattributed  unattributed
#
#       params_campaign params_medium params_term is_first_activity  \
# 0                 NaN           NaN         NaN             False
# 1                 NaN           NaN         NaN             False
# 2                 NaN           NaN         NaN             False
# 3                 NaN           NaN         NaN             False
# 4                 NaN           NaN         NaN              True
# ...               ...           ...         ...               ...
# 60829             NaN           NaN         NaN             False
# 60830             NaN           NaN         NaN              True
# 60831             NaN           NaN         NaN              True
# 60832             NaN           NaN         NaN              True
# 60833             NaN           NaN         NaN             False
#
#       is_first_goal_activity  lv1   lv2  view_desc funnel_name funnel_desc  \
# 0                      False   14  1400       상품상세         gig          상품
# 1                      False   14  1400       상품상세         gig          상품
# 2                      False   14  1400       상품상세         gig          상품
# 3                      False   14  1400       상품상세         gig          상품
# 4                      False   14  1400       상품상세         gig          상품
# ...                      ...  ...   ...        ...         ...         ...
# 60829                  False   12  1200  카테고리-상품목록    category        카테고리
# 60830                  False   12  1200  카테고리-상품목록    category        카테고리
# 60831                  False   12  1200  카테고리-상품목록    category        카테고리
# 60832                  False   12  1200  카테고리-상품목록    category        카테고리
# 60833                  False   12  1200  카테고리-상품목록    category        카테고리
#
#        depth  category_id category_name  category1_id  category2_id  \
# 0          3        41201         자기소개서             4         412.0
# 1          3        41201         자기소개서             4         412.0
# 2          3        41201         자기소개서             4         412.0
# 3          3        41201         자기소개서             4         412.0
# 4          3        41201         자기소개서             4         412.0
# ...      ...          ...           ...           ...           ...
# 60829      2          612        데이터베이스             6         612.0
# 60830      2          612        데이터베이스             6         612.0
# 60831      2          612        데이터베이스             6         612.0
# 60832      2          612        데이터베이스             6         612.0
# 60833      2          612        데이터베이스             6         612.0
#
#        category3_id category1  category2 category3
# 0           41201.0      문서작성  자기소개서·이력서     자기소개서
# 1           41201.0      문서작성  자기소개서·이력서     자기소개서
# 2           41201.0      문서작성  자기소개서·이력서     자기소개서
# 3           41201.0      문서작성  자기소개서·이력서     자기소개서
# 4           41201.0      문서작성  자기소개서·이력서     자기소개서
# ...             ...       ...        ...       ...
# 60829           NaN  IT·프로그래밍     데이터베이스       NaN
# 60830           NaN  IT·프로그래밍     데이터베이스       NaN
# 60831           NaN  IT·프로그래밍     데이터베이스       NaN
# 60832           NaN  IT·프로그래밍     데이터베이스       NaN
# 60833           NaN  IT·프로그래밍     데이터베이스       NaN
#
# [60834 rows x 42 columns]

# %% [markdown]
# **14. 합친 데이터에서 필요하지 않은 컬럼은 버려주세요.**
#
# 이제 데이터를 다 정리하고 합쳤으면, 나머지는 분석에 필요하지 않은 데이터를 버려주는 일만 남았습니다. 실제 회사에서는 데이터를 처음 읽을 때 굉장히 많은 컬럼을 읽어오게 되는데, 이를 전부 읽어와 분석하지 않고 1) 필요하지 않은 컬럼은 사전에 버려주고, 2) 남은 데이터에서 분석할 때 필요한 데이터만 그때그때 가져오는 습관을 드리는 것이 좋습니다.
#
# 그러므로 다음의 컬럼은 사용하지 않을 예정이니 데이터에서 삭제하도록 하겠습니다.
#
#   * ```in_app_event_category```
#   * ```in_app_event_label```
#   * ```source_type```
#   * ```Lv1```, ```Lv2```
#   * ```funnel_name```, ```depth```
#   * ```category_id```, ```category1_id```, ```category2_id```, ```category3_id```
#
# 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe", style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>row_uuid</th>
#             <th>app_package_name</th>
#             <th>user_id</th>
#             <th>event_datetime</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>device_manufacturer</th>
#             <th>device_type</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>app_version</th>
#             <th>event_category</th>
#             <th>view_category</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>funnel_desc</th>
#             <th>view_desc</th>
#             <th>category_name</th>
#             <th>category1</th>
#             <th>category2</th>
#             <th>category3</th>
#             <th>channel</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>is_first_activity</th>
#             <th>is_first_goal_activity</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>com.kmong.iOS</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#             <td>홈</td>
#             <td>홈 (탭)</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>com.kmong.kmong</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Samsung</td>
#             <td>SM-N935S</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>3.3.5</td>
#             <td>goal</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>상품</td>
#             <td>상품상세</td>
#             <td>자기소개서</td>
#             <td>문서작성</td>
#             <td>자기소개서·이력서</td>
#             <td>자기소개서</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>com.kmong.iOS</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>메시지</td>
#             <td>메시지목록-상세</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>com.kmong.iOS</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>com.kmong.iOS</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>거래관리</td>
#             <td>메뉴목록-구매관리-거래메시지</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>web</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#     </tbody>
# </table>

# %%
# 위에서 명시한 조건에 맞게 컬럼의 순서를 변경합니다.
# 이를 new_columns라는 이름의 변수에 파이썬 리스트로 집어넣습니다.
new_columns = [
    'row_uuid', 'app_package_name', 'user_id', 
    'event_datetime', 'event_datetime_year', 'event_datetime_month', 'event_datetime_day',
    'event_datetime_hour', 'event_datetime_minute', 'event_datetime_second',
    'device_manufacturer', 'device_type', 'os_type', 'os_version',
    'app_version', 'event_category', 'view_category', 'view_id', 'view_action', 
    'funnel_desc','view_desc', 
    'category_name', 'category1', 'category2', 'category3',
    'channel', 'params_campaign', 'params_medium', 'params_term', 
    'is_first_activity', 'is_first_goal_activity'
]

# merge_data = merge_data.drop(['in_app_event_category','in_app_event_label','source_type',
#                              'lv1','lv2','funnel_name','depth','category_id','category1_id',
#                              'category2_id','category3_id'],axis=1)

merge_data.columns = new_columns
merge_data
# Write your code here!
# Out:
#                                    row_uuid app_package_name  \
# 0      e62dccef-dd70-4415-8a33-c8324ddaed38  com.kmong.kmong
# 1      a6d462c3-d4a3-4a2c-8942-88f2cae0012e  com.kmong.kmong
# 2      7d06d33e-cd1f-4064-a3d3-cb947424ff97  com.kmong.kmong
# 3      497ae46f-6749-4094-853f-d5b0b33e18fc  com.kmong.kmong
# 4      291c4d91-86c2-4102-b6c9-070bee255a4d  com.kmong.kmong
# ...                                     ...              ...
# 60829  180a016e-db8d-4c65-a676-dd3621ac444a  com.kmong.kmong
# 60830  4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013  com.kmong.kmong
# 60831  7868ecf3-0a2a-4ca6-a538-a898f1638bfe  com.kmong.kmong
# 60832  3e2d3015-bbf8-45a9-b2ca-c99e722dfba3  com.kmong.kmong
# 60833  5df94f15-09cd-4f3e-81fb-5957320a5c80  com.kmong.kmong
#
#                                     user_id            event_datetime  \
# 0      8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:00+09:00
# 1      8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:02+09:00
# 2      8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:03+09:00
# 3      8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:06+09:00
# 4      8a871e50-0717-4aed-9bad-04ac3c3793be 2018-09-28 00:00:28+09:00
# ...                                     ...                       ...
# 60829  7f345e9b-fa52-4a9c-9691-2986091bc264 2018-09-29 15:01:12+09:00
# 60830  8621f34b-ae3c-4c92-9b1d-b6187048a693 2018-09-29 16:35:58+09:00
# 60831  2a67e931-055c-4798-81f3-c87aad419284 2018-09-29 19:45:58+09:00
# 60832  fc5b560c-20aa-470a-a3da-e92177d16bc5 2018-09-29 20:50:35+09:00
# 60833  fc5b560c-20aa-470a-a3da-e92177d16bc5 2018-09-29 20:51:08+09:00
#
#        event_datetime_year  event_datetime_month  event_datetime_day  \
# 0                     2018                     9                  28
# 1                     2018                     9                  28
# 2                     2018                     9                  28
# 3                     2018                     9                  28
# 4                     2018                     9                  28
# ...                    ...                   ...                 ...
# 60829                 2018                     9                  29
# 60830                 2018                     9                  29
# 60831                 2018                     9                  29
# 60832                 2018                     9                  29
# 60833                 2018                     9                  29
#
#        event_datetime_hour  event_datetime_minute  event_datetime_second  \
# 0                        0                      0                      0
# 1                        0                      0                      2
# 2                        0                      0                      3
# 3                        0                      0                      6
# 4                        0                      0                     28
# ...                    ...                    ...                    ...
# 60829                   15                      1                     12
# 60830                   16                     35                     58
# 60831                   19                     45                     58
# 60832                   20                     50                     35
# 60833                   20                     51                      8
#
#       device_manufacturer device_type  os_type os_version app_version  \
# 0                 Samsung    SM-N935S  Android        7.0       3.3.5
# 1                 Samsung    SM-N935S  Android        7.0       3.3.5
# 2                 Samsung    SM-N935S  Android        7.0       3.3.5
# 3                 Samsung    SM-N935S  Android        7.0       3.3.5
# 4                 Samsung    SM-N935S  Android        7.0       3.3.5
# ...                   ...         ...      ...        ...         ...
# 60829                  LG   LGM-V300S  Android      8.0.0       3.3.5
# 60830             Samsung    SM-G930K  Android        7.0       3.3.5
# 60831             Samsung    SM-N960N  Android      8.1.0       3.3.5
# 60832             Samsung    SM-G930S  Android      8.0.0       3.3.5
# 60833             Samsung    SM-G930S  Android      8.0.0       3.3.5
#
#       event_category view_category       view_id view_action   funnel_desc  \
# 0               goal           gig    gig_detail        view  unattributed
# 1               goal           gig    gig_detail        view  unattributed
# 2               goal           gig    gig_detail        view  unattributed
# 3               goal           gig    gig_detail        view  unattributed
# 4               goal           gig    gig_detail        view  unattributed
# ...              ...           ...           ...         ...           ...
# 60829           goal      category  category_gig        view  unattributed
# 60830           goal      category  category_gig        view  unattributed
# 60831           goal      category  category_gig        view  unattributed
# 60832           goal      category  category_gig        view  unattributed
# 60833           goal      category  category_gig        view  unattributed
#
#       view_desc category_name category1 category2 category3    channel  \
# 0           NaN           NaN       NaN     False     False       상품상세
# 1           NaN           NaN       NaN     False     False       상품상세
# 2           NaN           NaN       NaN     False     False       상품상세
# 3           NaN           NaN       NaN     False     False       상품상세
# 4           NaN           NaN       NaN      True     False       상품상세
# ...         ...           ...       ...       ...       ...        ...
# 60829       NaN           NaN       NaN     False     False  카테고리-상품목록
# 60830       NaN           NaN       NaN      True     False  카테고리-상품목록
# 60831       NaN           NaN       NaN      True     False  카테고리-상품목록
# 60832       NaN           NaN       NaN      True     False  카테고리-상품목록
# 60833       NaN           NaN       NaN     False     False  카테고리-상품목록
#
#       params_campaign params_medium params_term is_first_activity  \
# 0                  상품         자기소개서        문서작성         자기소개서·이력서
# 1                  상품         자기소개서        문서작성         자기소개서·이력서
# 2                  상품         자기소개서        문서작성         자기소개서·이력서
# 3                  상품         자기소개서        문서작성         자기소개서·이력서
# 4                  상품         자기소개서        문서작성         자기소개서·이력서
# ...               ...           ...         ...               ...
# 60829            카테고리        데이터베이스    IT·프로그래밍            데이터베이스
# 60830            카테고리        데이터베이스    IT·프로그래밍            데이터베이스
# 60831            카테고리        데이터베이스    IT·프로그래밍            데이터베이스
# 60832            카테고리        데이터베이스    IT·프로그래밍            데이터베이스
# 60833            카테고리        데이터베이스    IT·프로그래밍            데이터베이스
#
#       is_first_goal_activity
# 0                      자기소개서
# 1                      자기소개서
# 2                      자기소개서
# 3                      자기소개서
# 4                      자기소개서
# ...                      ...
# 60829                    NaN
# 60830                    NaN
# 60831                    NaN
# 60832                    NaN
# 60833                    NaN
#
# [60834 rows x 31 columns]

# %% [markdown]
# **15. ```row_uuid```를 인덱스(index)로 지정해주세요.**
#
# 데이터를 다 정리했으면 마지막으로 인덱스(index)를 지정하고 마무리하겠습니다. 현재 가지고 있는 데이터에서 인덱스가 될 수 있을만한 컬럼은 ```row_uuid``` 입니다. 이 컬럼을 인덱스로 지정하면, 앞으로 데이터의 행(row)을 가져오고 분석할 때 큰 도움이 될 것 같습니다. 최종적으로는 다음의 결과가 나와야 합니다.

# %% [markdown]
# <table border="1" class="dataframe" style="float: left;">
#     <thead>
#         <tr style="text-align: right;">
#             <th></th>
#             <th>row_uuid</th>
#             <th>app_package_name</th>
#             <th>user_id</th>
#             <th>event_datetime</th>
#             <th>event_datetime_year</th>
#             <th>event_datetime_month</th>
#             <th>event_datetime_day</th>
#             <th>event_datetime_hour</th>
#             <th>event_datetime_minute</th>
#             <th>event_datetime_second</th>
#             <th>device_manufacturer</th>
#             <th>device_type</th>
#             <th>os_type</th>
#             <th>os_version</th>
#             <th>app_version</th>
#             <th>event_category</th>
#             <th>view_category</th>
#             <th>view_id</th>
#             <th>view_action</th>
#             <th>funnel_desc</th>
#             <th>view_desc</th>
#             <th>category_name</th>
#             <th>category1</th>
#             <th>category2</th>
#             <th>category3</th>
#             <th>channel</th>
#             <th>params_campaign</th>
#             <th>params_medium</th>
#             <th>params_term</th>
#             <th>is_first_activity</th>
#             <th>is_first_goal_activity</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>0</th>
#             <td>fd2a188c-bc9b-4702-9c47-b546b2614817</td>
#             <td>com.kmong.iOS</td>
#             <td>F36FAA62-ADAC-4AA5-9B00-1FD6CB7EE957</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>home</td>
#             <td>home</td>
#             <td>view</td>
#             <td>홈</td>
#             <td>홈 (탭)</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>1</th>
#             <td>e62dccef-dd70-4415-8a33-c8324ddaed38</td>
#             <td>com.kmong.kmong</td>
#             <td>8a871e50-0717-4aed-9bad-04ac3c3793be</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Samsung</td>
#             <td>SM-N935S</td>
#             <td>Android</td>
#             <td>7.0</td>
#             <td>3.3.5</td>
#             <td>goal</td>
#             <td>gig</td>
#             <td>gig_detail</td>
#             <td>view</td>
#             <td>상품</td>
#             <td>상품상세</td>
#             <td>자기소개서</td>
#             <td>문서작성</td>
#             <td>자기소개서·이력서</td>
#             <td>자기소개서</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>2</th>
#             <td>14eb3197-db83-493a-b7be-83582960c40b</td>
#             <td>com.kmong.iOS</td>
#             <td>A9E5778A-8F3D-4597-9718-74BF953A9F64</td>
#             <td>2018-09-27 15:00:00</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>0</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>12.0</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>inbox</td>
#             <td>inbox_detail</td>
#             <td>view</td>
#             <td>메시지</td>
#             <td>메시지목록-상세</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>unattributed</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#         <tr>
#             <th>3</th>
#             <td>f9bb91af-248b-44dc-9f5c-1c00b37ea97b</td>
#             <td>com.kmong.iOS</td>
#             <td>168761CB-CB67-4592-867D-52780D651297</td>
#             <td>2018-09-27 15:00:01</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>foreground</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#         </tr>
#         <tr>
#             <th>4</th>
#             <td>236e9946-7801-4898-b609-06c8ab1139dc</td>
#             <td>com.kmong.iOS</td>
#             <td>ACABB7C0-4C76-413A-B314-E5D6DA0D0E5D</td>
#             <td>2018-09-27 15:00:02</td>
#             <td>2018</td>
#             <td>9</td>
#             <td>27</td>
#             <td>15</td>
#             <td>0</td>
#             <td>2</td>
#             <td>Apple</td>
#             <td>iPhone</td>
#             <td>iOS</td>
#             <td>11.4.1</td>
#             <td>4.0.4</td>
#             <td>goal</td>
#             <td>buyer</td>
#             <td>buyer_order_track</td>
#             <td>view</td>
#             <td>거래관리</td>
#             <td>메뉴목록-구매관리-거래메시지</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>web</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>NaN</td>
#             <td>False</td>
#             <td>False</td>
#         </tr>
#     </tbody>
# </table>

# %%
# Write your code here!
merge_data = merge_data.set_index('row_uuid')
merge_data
# Out:
#                                      app_package_name  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38  com.kmong.kmong
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e  com.kmong.kmong
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97  com.kmong.kmong
# 497ae46f-6749-4094-853f-d5b0b33e18fc  com.kmong.kmong
# 291c4d91-86c2-4102-b6c9-070bee255a4d  com.kmong.kmong
# ...                                               ...
# 180a016e-db8d-4c65-a676-dd3621ac444a  com.kmong.kmong
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013  com.kmong.kmong
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe  com.kmong.kmong
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3  com.kmong.kmong
# 5df94f15-09cd-4f3e-81fb-5957320a5c80  com.kmong.kmong
#
#                                                                    user_id  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38  8a871e50-0717-4aed-9bad-04ac3c3793be
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e  8a871e50-0717-4aed-9bad-04ac3c3793be
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97  8a871e50-0717-4aed-9bad-04ac3c3793be
# 497ae46f-6749-4094-853f-d5b0b33e18fc  8a871e50-0717-4aed-9bad-04ac3c3793be
# 291c4d91-86c2-4102-b6c9-070bee255a4d  8a871e50-0717-4aed-9bad-04ac3c3793be
# ...                                                                    ...
# 180a016e-db8d-4c65-a676-dd3621ac444a  7f345e9b-fa52-4a9c-9691-2986091bc264
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013  8621f34b-ae3c-4c92-9b1d-b6187048a693
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe  2a67e931-055c-4798-81f3-c87aad419284
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3  fc5b560c-20aa-470a-a3da-e92177d16bc5
# 5df94f15-09cd-4f3e-81fb-5957320a5c80  fc5b560c-20aa-470a-a3da-e92177d16bc5
#
#                                                 event_datetime  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38 2018-09-28 00:00:00+09:00
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e 2018-09-28 00:00:02+09:00
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97 2018-09-28 00:00:03+09:00
# 497ae46f-6749-4094-853f-d5b0b33e18fc 2018-09-28 00:00:06+09:00
# 291c4d91-86c2-4102-b6c9-070bee255a4d 2018-09-28 00:00:28+09:00
# ...                                                        ...
# 180a016e-db8d-4c65-a676-dd3621ac444a 2018-09-29 15:01:12+09:00
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013 2018-09-29 16:35:58+09:00
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe 2018-09-29 19:45:58+09:00
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3 2018-09-29 20:50:35+09:00
# 5df94f15-09cd-4f3e-81fb-5957320a5c80 2018-09-29 20:51:08+09:00
#
#                                       event_datetime_year  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38                 2018
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e                 2018
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97                 2018
# 497ae46f-6749-4094-853f-d5b0b33e18fc                 2018
# 291c4d91-86c2-4102-b6c9-070bee255a4d                 2018
# ...                                                   ...
# 180a016e-db8d-4c65-a676-dd3621ac444a                 2018
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013                 2018
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe                 2018
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3                 2018
# 5df94f15-09cd-4f3e-81fb-5957320a5c80                 2018
#
#                                       event_datetime_month  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38                     9
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e                     9
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97                     9
# 497ae46f-6749-4094-853f-d5b0b33e18fc                     9
# 291c4d91-86c2-4102-b6c9-070bee255a4d                     9
# ...                                                    ...
# 180a016e-db8d-4c65-a676-dd3621ac444a                     9
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013                     9
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe                     9
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3                     9
# 5df94f15-09cd-4f3e-81fb-5957320a5c80                     9
#
#                                       event_datetime_day  event_datetime_hour  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38                  28                    0
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e                  28                    0
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97                  28                    0
# 497ae46f-6749-4094-853f-d5b0b33e18fc                  28                    0
# 291c4d91-86c2-4102-b6c9-070bee255a4d                  28                    0
# ...                                                  ...                  ...
# 180a016e-db8d-4c65-a676-dd3621ac444a                  29                   15
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013                  29                   16
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe                  29                   19
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3                  29                   20
# 5df94f15-09cd-4f3e-81fb-5957320a5c80                  29                   20
#
#                                       event_datetime_minute  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38                      0
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e                      0
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97                      0
# 497ae46f-6749-4094-853f-d5b0b33e18fc                      0
# 291c4d91-86c2-4102-b6c9-070bee255a4d                      0
# ...                                                     ...
# 180a016e-db8d-4c65-a676-dd3621ac444a                      1
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013                     35
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe                     45
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3                     50
# 5df94f15-09cd-4f3e-81fb-5957320a5c80                     51
#
#                                       event_datetime_second  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38                      0
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e                      2
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97                      3
# 497ae46f-6749-4094-853f-d5b0b33e18fc                      6
# 291c4d91-86c2-4102-b6c9-070bee255a4d                     28
# ...                                                     ...
# 180a016e-db8d-4c65-a676-dd3621ac444a                     12
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013                     58
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe                     58
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3                     35
# 5df94f15-09cd-4f3e-81fb-5957320a5c80                      8
#
#                                      device_manufacturer device_type  os_type  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38             Samsung    SM-N935S  Android
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e             Samsung    SM-N935S  Android
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97             Samsung    SM-N935S  Android
# 497ae46f-6749-4094-853f-d5b0b33e18fc             Samsung    SM-N935S  Android
# 291c4d91-86c2-4102-b6c9-070bee255a4d             Samsung    SM-N935S  Android
# ...                                                  ...         ...      ...
# 180a016e-db8d-4c65-a676-dd3621ac444a                  LG   LGM-V300S  Android
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013             Samsung    SM-G930K  Android
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe             Samsung    SM-N960N  Android
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3             Samsung    SM-G930S  Android
# 5df94f15-09cd-4f3e-81fb-5957320a5c80             Samsung    SM-G930S  Android
#
#                                      os_version app_version event_category  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38        7.0       3.3.5           goal
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e        7.0       3.3.5           goal
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97        7.0       3.3.5           goal
# 497ae46f-6749-4094-853f-d5b0b33e18fc        7.0       3.3.5           goal
# 291c4d91-86c2-4102-b6c9-070bee255a4d        7.0       3.3.5           goal
# ...                                         ...         ...            ...
# 180a016e-db8d-4c65-a676-dd3621ac444a      8.0.0       3.3.5           goal
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013        7.0       3.3.5           goal
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe      8.1.0       3.3.5           goal
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3      8.0.0       3.3.5           goal
# 5df94f15-09cd-4f3e-81fb-5957320a5c80      8.0.0       3.3.5           goal
#
#                                      view_category       view_id view_action  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38           gig    gig_detail        view
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e           gig    gig_detail        view
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97           gig    gig_detail        view
# 497ae46f-6749-4094-853f-d5b0b33e18fc           gig    gig_detail        view
# 291c4d91-86c2-4102-b6c9-070bee255a4d           gig    gig_detail        view
# ...                                            ...           ...         ...
# 180a016e-db8d-4c65-a676-dd3621ac444a      category  category_gig        view
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013      category  category_gig        view
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe      category  category_gig        view
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3      category  category_gig        view
# 5df94f15-09cd-4f3e-81fb-5957320a5c80      category  category_gig        view
#
#                                        funnel_desc view_desc category_name  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38  unattributed       NaN           NaN
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e  unattributed       NaN           NaN
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97  unattributed       NaN           NaN
# 497ae46f-6749-4094-853f-d5b0b33e18fc  unattributed       NaN           NaN
# 291c4d91-86c2-4102-b6c9-070bee255a4d  unattributed       NaN           NaN
# ...                                            ...       ...           ...
# 180a016e-db8d-4c65-a676-dd3621ac444a  unattributed       NaN           NaN
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013  unattributed       NaN           NaN
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe  unattributed       NaN           NaN
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3  unattributed       NaN           NaN
# 5df94f15-09cd-4f3e-81fb-5957320a5c80  unattributed       NaN           NaN
#
#                                      category1 category2 category3    channel  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38       NaN     False     False       상품상세
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e       NaN     False     False       상품상세
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97       NaN     False     False       상품상세
# 497ae46f-6749-4094-853f-d5b0b33e18fc       NaN     False     False       상품상세
# 291c4d91-86c2-4102-b6c9-070bee255a4d       NaN      True     False       상품상세
# ...                                        ...       ...       ...        ...
# 180a016e-db8d-4c65-a676-dd3621ac444a       NaN     False     False  카테고리-상품목록
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013       NaN      True     False  카테고리-상품목록
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe       NaN      True     False  카테고리-상품목록
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3       NaN      True     False  카테고리-상품목록
# 5df94f15-09cd-4f3e-81fb-5957320a5c80       NaN     False     False  카테고리-상품목록
#
#                                      params_campaign params_medium  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38              상품         자기소개서
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e              상품         자기소개서
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97              상품         자기소개서
# 497ae46f-6749-4094-853f-d5b0b33e18fc              상품         자기소개서
# 291c4d91-86c2-4102-b6c9-070bee255a4d              상품         자기소개서
# ...                                              ...           ...
# 180a016e-db8d-4c65-a676-dd3621ac444a            카테고리        데이터베이스
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013            카테고리        데이터베이스
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe            카테고리        데이터베이스
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3            카테고리        데이터베이스
# 5df94f15-09cd-4f3e-81fb-5957320a5c80            카테고리        데이터베이스
#
#                                      params_term is_first_activity  \
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38        문서작성         자기소개서·이력서
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e        문서작성         자기소개서·이력서
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97        문서작성         자기소개서·이력서
# 497ae46f-6749-4094-853f-d5b0b33e18fc        문서작성         자기소개서·이력서
# 291c4d91-86c2-4102-b6c9-070bee255a4d        문서작성         자기소개서·이력서
# ...                                          ...               ...
# 180a016e-db8d-4c65-a676-dd3621ac444a    IT·프로그래밍            데이터베이스
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013    IT·프로그래밍            데이터베이스
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe    IT·프로그래밍            데이터베이스
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3    IT·프로그래밍            데이터베이스
# 5df94f15-09cd-4f3e-81fb-5957320a5c80    IT·프로그래밍            데이터베이스
#
#                                      is_first_goal_activity
# row_uuid
# e62dccef-dd70-4415-8a33-c8324ddaed38                  자기소개서
# a6d462c3-d4a3-4a2c-8942-88f2cae0012e                  자기소개서
# 7d06d33e-cd1f-4064-a3d3-cb947424ff97                  자기소개서
# 497ae46f-6749-4094-853f-d5b0b33e18fc                  자기소개서
# 291c4d91-86c2-4102-b6c9-070bee255a4d                  자기소개서
# ...                                                     ...
# 180a016e-db8d-4c65-a676-dd3621ac444a                    NaN
# 4cfe75a4-8f67-4f53-8c3e-aaacb3aa5013                    NaN
# 7868ecf3-0a2a-4ca6-a538-a898f1638bfe                    NaN
# 3e2d3015-bbf8-45a9-b2ca-c99e722dfba3                    NaN
# 5df94f15-09cd-4f3e-81fb-5957320a5c80                    NaN
#
# [60834 rows x 30 columns]

# %% [markdown]
# **16. data 변수에 할당된 데이터의 행렬 사이즈를 출력하세요 .**
#
# print(data.shape) 한 결과

# %%
print(merge_data.shape)
# Out:
# (60834, 30)

# %% [markdown]
# ## [ 제출 ]
#
# 1. 위 마지막 작업 결과를 csv 파일로 저장합니다.
#
#
# 2. 현재 파일을 pdf 파일을 만들어 제출합니다.

# %%
merge_data.to_csv('./data/merge_data.csv',mode='w')

# %% [markdown]
# ## [추가] 조별로 인사이드를 도출하여 분석에 대한 결론을 낸다
